# %% [markdown]
# # FASDD_CV — YOLO11m-seg: EDA + Preprocessing + Resume Training
#
# **Pipeline:** `labels_seg_refined/labels_seg_refined` (SAM2 + MaskRefine-v2 labels) → Comprehensive EDA → Preprocessing → YOLO11m-seg Resume/Training
#
# **Sections:**
# - **S0.** Configuration *(only cell you need to edit)*
# - **S1.** Experiment Tracking — wandb (L1) · Config snapshot (L2) · Registry CSV (L3)
# - **S2.** Environment Setup
# - **S3.** Restore Working Directory (FASDD_CV · labels_seg_refined · labels_fixed · splits)
# - **S4.** Load GT Annotations
# - **S5.** Comprehensive EDA on Seg Masks
# - **S6.** Preprocessing → `labels_seg_clean` (dedup + degenerate removal)
# - **S7.** Build YAML + Symlinks for Seg Training
# - **S8.** YOLO11m-seg Resume/Fresh Training
# - **S9.** Post-Training Logging
# - **S10.** Evaluation on Test Split
# - **S11.** Inference Spot-Check
# - **S12.** Save Checkpoints

# %% [markdown]
# ## S0. Configuration
# Edit **only this cell**. Everything else derives from it.

# %%
# !zip -r fasdd_cv.zip fasdd_cv
# Out:
#   adding: fasdd_cv/ (stored 0%)
#   adding: fasdd_cv/yolo11m_seg_finetune_imgsz1024_20260613-2/ (stored 0%)
#   adding: fasdd_cv/yolo11m_seg_finetune_imgsz1024_20260613-2/train_batch1.jpg (deflated 13%)
#   adding: fasdd_cv/yolo11m_seg_finetune_imgsz1024_20260613-2/labels.jpg (deflated 24%)
#   adding: fasdd_cv/yolo11m_seg_finetune_imgsz1024_20260613-2/results.csv (deflated 65%)
#   adding: fasdd_cv/yolo11m_seg_finetune_imgsz1024_20260613-2/train_batch2.jpg (deflated 8%)
#   adding: fasdd_cv/yolo11m_seg_finetune_imgsz1024_20260613-2/args.yaml (deflated 57%)
#   adding: fasdd_cv/yolo11m_seg_finetune_imgsz1024_20260613-2/train_batch0.jpg (deflated 7%)
#   adding: fasdd_cv/yolo11m_seg_finetune_imgsz1024_20260613-2/run_config.json (deflated 63%)
#   adding: fasdd_cv/yolo11m_seg_finetune_imgsz1024_20260613-2/weights/ (stored 0%)
#   adding: fasdd_cv/yolo11m_seg_finetune_imgsz1024_20260613-2/weights/best.pt (deflated 8%)
#   adding: fasdd_cv/yolo11m_seg_finetune_imgsz1024_20260613-2/weights/last.pt (deflated 8%)

# %%
# =============================================================================
#  S0 — CONFIGURATION  (only cell you need to edit)
# =============================================================================
import os
from datetime import datetime
from pathlib import Path

# ── Kaggle dataset paths ──────────────────────────────────────────────────────
# kayempee → ctcaothanhbang (account rename)
BASE_DIR = "/kaggle/input/datasets/ctcaothanhbang/dataset-v2/FASDD_CV/FASDD_CV"

# Correct refined segmentation labels directory.
# This notebook uses this directory directly as raw seg labels, then writes cleaned labels to /kaggle/working/labels_seg_clean.
LABELS_SEG_SOURCE = Path("/kaggle/input/datasets/ctcaothanhbang/storage/labels_seg_refined/labels_seg_refined")

# Dataset chứa labels_fixed + train/val/test yamls (từ detection baseline)
TRAINING_DATA_INPUT = Path("/kaggle/input/fasdd-training-data")

# ── Model ─────────────────────────────────────────────────────────────────────
TRAIN_MODE     = "finetune"        # "finetune" | "scratch"
YOLO_SIZE      = "m"
SEG_MODEL_INIT = f"yolo11{YOLO_SIZE}-seg.pt"

# ── Resume checkpoint ─────────────────────────────────────────────────────────
# True  → copy run folder from /kaggle/input to /kaggle/working and resume from weights/last.pt.
# False → start a fresh run from SEG_MODEL_INIT.
RESUME_TRAINING = True

RESUME_RUN_INPUT = Path(
    "/kaggle/input/datasets/ctcaothanhbang/storage/fasdd_cv/fasdd_cv/"
    "yolo11m_seg_finetune_imgsz1024_20260613-2"
)
RESUME_LAST_PT = RESUME_RUN_INPUT / "weights" / "last.pt"
RESUME_BEST_PT = RESUME_RUN_INPUT / "weights" / "best.pt"

# ── Training hyperparams (follow project-phase1-vdt.ipynb) ───────────────────
# For true resume, Ultralytics continues optimizer/LR/epoch state from last.pt.
# EPOCHS is still written into args.yaml before resume so you can extend total epochs if needed.
IMGSZ         = 1024
EPOCHS        = 100
BATCH         = 16       # dual T4: ~8/GPU at imgsz=1024
WORKERS       = 4
LR0           = 0.01
LRF           = 0.01
USE_MULTI_GPU = True
SEED          = 42

# ── Augmentation (EDA-derived — identical to detection baseline) ──────────────
AUGMENT_HSV_H     = 0.015
AUGMENT_HSV_S     = 0.700
AUGMENT_HSV_V     = 0.400
AUGMENT_FLIPUD    = 0.0
AUGMENT_DEGREES   = 0.0
AUGMENT_TRANSLATE = 0.2   # smoke center-X bias fix
AUGMENT_SCALE     = 0.5

# ── Experiment tracking ───────────────────────────────────────────────────────
WANDB_PROJECT  = "fasdd-cv"
WANDB_ENABLED  = True
EXPERIMENT_NOTES = (
    "Seg: resume yolo11m-seg imgsz=1024 from uploaded last.pt. "
    "Labels: labels_seg_refined directory. "
    "Full EDA + dedup/degenerate preprocess applied."
)

# ── Preprocessing ─────────────────────────────────────────────────────────────
MIN_BBOX_DIM              = 1e-4   # degenerate detection bbox filter
MIN_SEG_POINTS            = 3      # polygon must have >= this many points
BBOX_FALLBACK_FOR_MISSING = False  # True → create rect polygon for images with no seg

# ── Derived (do not edit) ─────────────────────────────────────────────────────
DATE_STR       = datetime.now().strftime("%Y%m%d")
FRESH_RUN_NAME = f"yolo11{YOLO_SIZE}_seg_{TRAIN_MODE}_imgsz{IMGSZ}_{DATE_STR}"
RESUME_RUN_NAME = RESUME_RUN_INPUT.name
RUN_NAME       = RESUME_RUN_NAME if RESUME_TRAINING else FRESH_RUN_NAME

WORK_DIR    = Path("/kaggle/working")
PROJECT_DIR = WORK_DIR / "fasdd_cv"
RUN_DIR     = PROJECT_DIR / RUN_NAME

LABELS_SEG_RAW   = LABELS_SEG_SOURCE             # read-only source labels from Kaggle input
LABELS_SEG_CLEAN = WORK_DIR / "labels_seg_clean" # after preprocessing (train)
LABELS_FIXED     = WORK_DIR / "labels_fixed"     # GT bbox labels (reference)
YAML_PATH        = WORK_DIR / "fasdd_cv_seg.yaml"

BASE_DIR_PATH = Path(BASE_DIR)
IMG_DIR       = BASE_DIR_PATH / "images"
LABEL_DIR     = BASE_DIR_PATH / "annotations" / "YOLO_CV" / "labels"
YOLO_ANN_DIR  = BASE_DIR_PATH / "annotations" / "YOLO_CV"
TRAIN_TXT     = YOLO_ANN_DIR / "train.txt"
VAL_TXT       = YOLO_ANN_DIR / "val.txt"
TEST_TXT      = YOLO_ANN_DIR / "test.txt"

TRAIN_LIST = WORK_DIR / "train_images.txt"
VAL_LIST   = WORK_DIR / "val_images.txt"
TEST_LIST  = WORK_DIR / "test_images.txt"

WORKING_IMAGES = WORK_DIR / "images"
WORKING_LABELS = WORK_DIR / "labels"

# Only create writable working directories here. Do not mkdir inside /kaggle/input.
for d in [LABELS_SEG_CLEAN, PROJECT_DIR]:
    d.mkdir(parents=True, exist_ok=True)

print("=" * 65)
print("FASDD_CV — YOLO11m-seg Seg Training")
print("=" * 65)
print(f"  Run name          : {RUN_NAME}")
print(f"  Resume training   : {RESUME_TRAINING}")
if RESUME_TRAINING:
    print(f"  Resume run input  : {RESUME_RUN_INPUT}")
    print(f"  Resume last.pt    : {RESUME_LAST_PT}")
print(f"  Model init        : {SEG_MODEL_INIT}")
print(f"  IMGSZ             : {IMGSZ}")
print(f"  EPOCHS            : {EPOCHS}  BATCH: {BATCH}  LR0: {LR0}")
print(f"  Multi-GPU         : {USE_MULTI_GPU}")
print(f"  LABELS_SEG_SOURCE : {LABELS_SEG_SOURCE}")
print(f"  WANDB             : {'enabled' if WANDB_ENABLED else 'disabled'}")
print("=" * 65)
# Out:
# =================================================================
# FASDD_CV — YOLO11m-seg Seg Training
# =================================================================
#   Run name          : yolo11m_seg_finetune_imgsz1024_20260613-2
#   Resume training   : True
#   Resume run input  : /kaggle/input/datasets/ctcaothanhbang/storage/fasdd_cv/fasdd_cv/yolo11m_seg_finetune_imgsz1024_20260613-2
#   Resume last.pt    : /kaggle/input/datasets/ctcaothanhbang/storage/fasdd_cv/fasdd_cv/yolo11m_seg_finetune_imgsz1024_20260613-2/weights/last.pt
#   Model init        : yolo11m-seg.pt
#   IMGSZ             : 1024
#   EPOCHS            : 100  BATCH: 16  LR0: 0.01
#   Multi-GPU         : True
#   LABELS_SEG_SOURCE : /kaggle/input/datasets/ctcaothanhbang/storage/labels_seg_refined/labels_seg_refined
#   WANDB             : enabled
# =================================================================

# %% [markdown]
# ## S1. Experiment Tracking
#
# Three layers (identical to detection baseline `project-phase1-vdt.ipynb`):
# - **Layer 1 — wandb**: real-time metric streaming
# - **Layer 2 — config snapshot**: `run_config.json` per run
# - **Layer 3 — registry CSV**: one row per run, accumulates all experiments

# %%
# !pip install ultralytics wandb --quiet
print("deps ready")
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 41.3/41.3 kB 1.5 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/1.3 MB 23.1 MB/s eta 0:00:00a 0:00:01
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 12.2/12.2 MB 67.0 MB/s eta 0:00:00:00:0100:01
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# dask-cuda 26.2.0 requires cuda-core==0.3.*, but you have cuda-core 1.0.1 which is incompatible.
# dask-cuda 26.2.0 requires numba-cuda<0.23.0,>=0.22.1, but you have numba-cuda 0.30.2 which is incompatible.
# distributed-ucxx-cu12 0.48.0 requires numba-cuda[cu12]<0.23.0,>=0.22.1, but you have numba-cuda 0.30.2 which is incompatible.
# cuml-cu12 26.2.0 requires numba<0.62.0,>=0.60.0, but you have numba 0.65.1 which is incompatible.
# cuml-cu12 26.2.0 requires numba-cuda[cu12]<0.23.0,>=0.22.1, but you have numba-cuda 0.30.2 which is incompatible.
# ucxx-cu12 0.48.0 requires numba-cuda[cu12]<0.23.0,>=0.22.1, but you have numba-cuda 0.30.2 which is incompatible.
# cudf-cu12 26.2.1 requires numba<0.62.0,>=0.60.0, but you have numba 0.65.1 which is incompatible.
# cudf-cu12 26.2.1 requires numba-cuda[cu12]<0.23.0,>=0.22.2, but you have numba-cuda 0.30.2 which is incompatible.
# deps ready

# %%
# =============================================================================
#  LAYER 1 — Weights & Biases
# =============================================================================
import wandb

if WANDB_ENABLED:
    try:
        from kaggle_secrets import UserSecretsClient
        os.environ["WANDB_API_KEY"] = UserSecretsClient().get_secret("WANDB_API_KEY")
        wandb.login(key=os.environ["WANDB_API_KEY"], relogin=True)
        print("wandb: logged in via Kaggle Secret")
    except Exception as e:
        print(f"Kaggle Secret not found ({e}) → offline mode")
        os.environ["WANDB_MODE"] = "offline"
        wandb.login(anonymous="allow")
else:
    os.environ["WANDB_MODE"] = "disabled"
    print("wandb: disabled")
# Out:
# wandb: WARNING The anonymous parameter to wandb.login() has no effect and will be removed in future versions.
# Kaggle Secret not found (Unexpected response from the service. Response: {'errors': ['No user secrets exist for kernel id 121735088 and label WANDB_API_KEY.'], 'error': {'code': 5}, 'wasSuccessful': False}.) → offline mode
# /usr/local/lib/python3.12/dist-packages/notebook/notebookapp.py:191: SyntaxWarning: invalid escape sequence '\/'
#   | |_| | '_ \/ _` / _` |  _/ -_)
# wandb: WARNING Unable to verify login in offline mode.

# %%
# =============================================================================
#  LAYER 2 — Config Snapshot
# =============================================================================
import json as _json

def save_run_config(run_dir: Path, extra: dict = None) -> Path:
    run_dir.mkdir(parents=True, exist_ok=True)
    cfg = {
        "run_name"       : RUN_NAME,
        "date"           : DATE_STR,
        "train_mode"     : TRAIN_MODE,
        "notes"          : EXPERIMENT_NOTES,
        "task"           : "segment",
        "model_family"   : "yolo11",
        "model_size"     : YOLO_SIZE,
        "model_init"     : SEG_MODEL_INIT,
        "resume_training": RESUME_TRAINING,
        "resume_run_input": str(RESUME_RUN_INPUT) if RESUME_TRAINING else None,
        "resume_last_pt"  : str(RESUME_LAST_PT) if RESUME_TRAINING else None,
        "dataset"        : "FASDD_CV",
        "imgsz"          : IMGSZ,
        "split"          : "official (train=47660 val=31770 test=15884)",
        "epochs"         : EPOCHS,
        "batch"          : BATCH,
        "workers"        : WORKERS,
        "lr0"            : LR0,
        "lrf"            : LRF,
        "warmup_epochs"  : 3.0,
        "mosaic"         : 1.0,
        "weight_decay"   : 0.0005,
        "patience"       : 50,
        "use_multi_gpu"  : USE_MULTI_GPU,
        "seed"           : SEED,
        "hsv_h"          : AUGMENT_HSV_H,
        "hsv_s"          : AUGMENT_HSV_S,
        "hsv_v"          : AUGMENT_HSV_V,
        "flipud"         : AUGMENT_FLIPUD,
        "degrees"        : AUGMENT_DEGREES,
        "translate"      : AUGMENT_TRANSLATE,
        "scale"          : AUGMENT_SCALE,
        "label_source"   : str(LABELS_SEG_SOURCE),
        "bbox_fallback"  : BBOX_FALLBACK_FOR_MISSING,
        "results": {
            # detection head
            "box_mAP50": None, "box_mAP50_fire": None,
            "box_mAP50_smoke": None, "box_mAP5095": None,
            # segmentation head
            "seg_mAP50": None, "seg_mAP50_fire": None,
            "seg_mAP50_smoke": None, "seg_mAP5095": None,
            "epochs_run": None, "inference_ms": None, "model_mb": None,
        }
    }
    if extra:
        cfg.update(extra)
    cfg_path = run_dir / "run_config.json"
    with open(cfg_path, "w") as f:
        _json.dump(cfg, f, indent=2)
    print(f"Config snapshot → {cfg_path}")
    return cfg_path

print("Layer 2 ready.")
# Out:
# Layer 2 ready.

# %%
# =============================================================================
#  LAYER 3 — Experiment Registry CSV
# =============================================================================
import pandas as pd

REGISTRY_PATH = WORK_DIR / "experiment_registry_seg.csv"

REGISTRY_COLUMNS = [
    "run_name", "date", "model", "mode", "imgsz", "epochs_run",
    # box head
    "box_mAP50", "box_mAP50_fire", "box_mAP50_smoke", "box_mAP5095",
    # seg head
    "seg_mAP50", "seg_mAP50_fire", "seg_mAP50_smoke", "seg_mAP5095",
    "AP_gap_smoke_minus_fire_box",
    "precision", "recall",
    "inference_ms_t4", "fps_t4", "model_mb", "onnx_mb",
    "notes", "wandb_run_url",
]

def load_registry():
    if REGISTRY_PATH.exists():
        return pd.read_csv(REGISTRY_PATH)
    return pd.DataFrame(columns=REGISTRY_COLUMNS)

def append_to_registry(row: dict):
    df = load_registry()
    for col in REGISTRY_COLUMNS:
        if col not in row:
            row[col] = None
    new_row = pd.DataFrame([{c: row.get(c) for c in REGISTRY_COLUMNS}])
    df = pd.concat([df, new_row], ignore_index=True)
    df.to_csv(REGISTRY_PATH, index=False)
    print(f"Registry updated: {REGISTRY_PATH}  ({len(df)} total runs)")
    return df

def show_registry():
    df = load_registry()
    if df.empty:
        print("Registry empty — no completed runs yet.")
        return df
    key_cols = ["run_name", "model", "mode", "imgsz", "epochs_run",
                "box_mAP50", "box_mAP50_fire", "seg_mAP50", "seg_mAP50_fire",
                "inference_ms_t4", "notes"]
    try:
        from IPython.display import display
        display(df[[c for c in key_cols if c in df.columns]])
    except:
        print(df[[c for c in key_cols if c in df.columns]].to_string())
    return df

print("Layer 3 ready.")
existing = load_registry()
print(f"Existing runs in registry: {len(existing)}")
if not existing.empty:
    show_registry()
# Out:
# Layer 3 ready.
# Existing runs in registry: 0

# %% [markdown]
# ## S2. Environment Setup

# %%
import random, warnings, time, zipfile, shutil
import numpy as np
import pandas as pd
import torch
import cv2
import matplotlib.pyplot as plt
import matplotlib.patches as mpatches
from collections import Counter, defaultdict
from pathlib import Path
from tqdm.auto import tqdm
import yaml

warnings.filterwarnings("ignore")

import ultralytics
print(f"ultralytics : {ultralytics.__version__}")
print(f"PyTorch     : {torch.__version__}")
print(f"CUDA        : {torch.cuda.is_available()}")
if torch.cuda.is_available():
    for i in range(torch.cuda.device_count()):
        name = torch.cuda.get_device_name(i)
        vram = torch.cuda.get_device_properties(i).total_memory / 1e9
        print(f"  GPU {i}: {name} ({vram:.1f} GB)")

# Seeds
random.seed(SEED)
np.random.seed(SEED)
torch.manual_seed(SEED)
if torch.cuda.is_available():
    torch.cuda.manual_seed_all(SEED)
# Out:
# Creating new Ultralytics Settings v0.0.6 file ✅
# View Ultralytics Settings with 'yolo settings' or at '/root/.config/Ultralytics/settings.json'
# Update Settings with 'yolo settings key=value', i.e. 'yolo settings runs_dir=path/to/dir'. For help see https://docs.ultralytics.com/quickstart/#ultralytics-settings.
# ultralytics : 8.4.67
# PyTorch     : 2.10.0+cu128
# CUDA        : True
#   GPU 0: Tesla T4 (15.6 GB)
#   GPU 1: Tesla T4 (15.6 GB)

# %% [markdown]
# ## S3. Restore Working Directory
#
# ### 3.1 Unzip FASDD_CV Dataset

# %%
# Unzip FASDD_CV (~11 GB) nếu chưa có
def find_data_root(base="/kaggle/input"):
    for candidate in [
        f"/kaggle/input/datasets/ctcaothanhbang/dataset-v2/FASDD_CV/FASDD_CV",
        "/kaggle/input/fasdd-cv/FASDD_CV",
    ]:
        if Path(candidate).is_dir() and (Path(candidate) / "images").is_dir():
            return candidate
    return None

data_root = find_data_root()
if data_root:
    print(f"Dataset found: {data_root}")
    # Update paths if needed
    if str(BASE_DIR_PATH) != data_root:
        print(f"  NOTE: BASE_DIR in S0 is different from found path — using found path")
    IMG_DIR   = Path(data_root) / "images"
    LABEL_DIR = Path(data_root) / "annotations" / "YOLO_CV" / "labels"
    YOLO_ANN_DIR = Path(data_root) / "annotations" / "YOLO_CV"
    TRAIN_TXT = YOLO_ANN_DIR / "train.txt"
    VAL_TXT   = YOLO_ANN_DIR / "val.txt"
    TEST_TXT  = YOLO_ANN_DIR / "test.txt"
else:
    print("ERROR: FASDD_CV dataset not found — check BASE_DIR in S0")

print(f"  IMG_DIR   : {IMG_DIR}  exists={IMG_DIR.exists()}")
print(f"  LABEL_DIR : {LABEL_DIR}  exists={LABEL_DIR.exists()}")
print(f"  TRAIN_TXT : {TRAIN_TXT.exists()}")
# Out:
# Dataset found: /kaggle/input/datasets/ctcaothanhbang/dataset-v2/FASDD_CV/FASDD_CV
#   IMG_DIR   : /kaggle/input/datasets/ctcaothanhbang/dataset-v2/FASDD_CV/FASDD_CV/images  exists=True
#   LABEL_DIR : /kaggle/input/datasets/ctcaothanhbang/dataset-v2/FASDD_CV/FASDD_CV/annotations/YOLO_CV/labels  exists=True
#   TRAIN_TXT : True

# %% [markdown]
# ### 3.2 Use `labels_seg_refined` Directory

# %%
# Use refined seg labels directory directly.
# Expected path:
#   /kaggle/input/datasets/ctcaothanhbang/storage/labels_seg_refined/labels_seg_refined
#
# Later steps read LABELS_SEG_RAW and write cleaned training labels to:
#   /kaggle/working/labels_seg_clean

assert LABELS_SEG_RAW.exists(), (
    f"\nERROR: LABELS_SEG_RAW does not exist:\n  {LABELS_SEG_RAW}\n"
    "Check LABELS_SEG_SOURCE in S0 and make sure the Kaggle dataset is attached."
)
assert LABELS_SEG_RAW.is_dir(), (
    f"\nERROR: LABELS_SEG_RAW is not a directory:\n  {LABELS_SEG_RAW}\n"
)

flat_txt = sorted(LABELS_SEG_RAW.glob("*.txt"))

# If the uploaded dataset has an extra nested directory, flatten it into /kaggle/working/labels_seg_raw.
# For your current requested path this should usually not run, because the .txt files should already be directly inside LABELS_SEG_RAW.
if len(flat_txt) == 0:
    nested_txt = sorted(LABELS_SEG_RAW.rglob("*.txt"))
    assert len(nested_txt) > 0, (
        f"\nERROR: no .txt label files found under:\n  {LABELS_SEG_RAW}\n"
    )

    WORK_RAW = WORK_DIR / "labels_seg_raw"
    if WORK_RAW.exists() or WORK_RAW.is_symlink():
        if WORK_RAW.is_symlink() or WORK_RAW.is_file():
            WORK_RAW.unlink()
        else:
            shutil.rmtree(WORK_RAW)
    WORK_RAW.mkdir(parents=True, exist_ok=True)

    seen_names = set()
    for src in tqdm(nested_txt, desc="Flatten labels_seg_refined", ncols=80):
        if src.name in seen_names:
            raise ValueError(f"Duplicate label filename found while flattening: {src.name}")
        seen_names.add(src.name)
        shutil.copy2(src, WORK_RAW / src.name)

    LABELS_SEG_RAW = WORK_RAW
    flat_txt = sorted(LABELS_SEG_RAW.glob("*.txt"))
    print(f"Flattened nested labels into: {LABELS_SEG_RAW}")

n_seg_files = len(flat_txt)
print(f"Using segmentation labels from: {LABELS_SEG_RAW}")
print(f"labels_seg_raw/refined files : {n_seg_files:,}")

# Basic sanity checks.
assert n_seg_files > 0, "ERROR: No .txt files found in refined segmentation label directory."
example_files = flat_txt[:3]
print("Examples:")
for p in example_files:
    print(f"  {p.name}")
# Out:
# Using segmentation labels from: /kaggle/input/datasets/ctcaothanhbang/storage/labels_seg_refined/labels_seg_refined
# labels_seg_raw/refined files : 56,086
# Examples:
#   bothFireAndSmoke_CV000000.txt
#   bothFireAndSmoke_CV000001.txt
#   bothFireAndSmoke_CV000002.txt

# %% [markdown]
# ### 3.3 Restore `labels_fixed` + Image Split Lists

# %%
# ── Option A: restore từ training-data Kaggle dataset ─────────────────────────
if TRAINING_DATA_INPUT.exists():
    if not LABELS_FIXED.exists():
        shutil.copytree(TRAINING_DATA_INPUT / "labels_fixed", LABELS_FIXED)
        print(f"Copied labels_fixed: {len(list(LABELS_FIXED.glob('*.txt'))):,} files")
    else:
        print(f"labels_fixed exists: {len(list(LABELS_FIXED.glob('*.txt'))):,} files")

    for f in ["fasdd_cv.yaml", "train_images.txt", "val_images.txt", "test_images.txt"]:
        src = TRAINING_DATA_INPUT / f
        if src.exists() and not (WORK_DIR / f).exists():
            shutil.copy(src, WORK_DIR / f)
            print(f"Copied: {f}")

# ── Option B: build from scratch using FASDD_CV annotations ──────────────────
else:
    print("TRAINING_DATA_INPUT not found — rebuilding from FASDD_CV annotations")

    def read_split_stems(txt_path: Path) -> list:
        stems = []
        if not txt_path.exists():
            return stems
        with open(txt_path) as f:
            for line in f:
                line = line.strip()
                if line:
                    stems.append(Path(line).stem)
        return stems

    train_stems = read_split_stems(TRAIN_TXT)
    val_stems   = read_split_stems(VAL_TXT)
    test_stems  = read_split_stems(TEST_TXT)
    print(f"Splits from FASDD_CV — train: {len(train_stems):,}  val: {len(val_stems):,}  test: {len(test_stems):,}")

    WORKING_IMAGES.unlink(missing_ok=True) if WORKING_IMAGES.is_symlink() else None
    WORKING_IMAGES.symlink_to(IMG_DIR)

    def write_img_list(stems, out_path):
        with open(out_path, "w") as f:
            for stem in stems:
                f.write(str(WORKING_IMAGES / (stem + ".jpg")) + "\n")

    write_img_list(train_stems, TRAIN_LIST)
    write_img_list(val_stems,   VAL_LIST)
    write_img_list(test_stems,  TEST_LIST)
    print("Image split lists written.")

print(f"\nTRAIN_LIST: {TRAIN_LIST.exists()}  ({sum(1 for _ in open(TRAIN_LIST))} lines)")
print(f"VAL_LIST  : {VAL_LIST.exists()}  ({sum(1 for _ in open(VAL_LIST))} lines)")
print(f"TEST_LIST : {TEST_LIST.exists()}  ({sum(1 for _ in open(TEST_LIST))} lines)")
# Out:
# TRAINING_DATA_INPUT not found — rebuilding from FASDD_CV annotations
# Splits from FASDD_CV — train: 47,660  val: 31,770  test: 15,884
# Image split lists written.
#
# TRAIN_LIST: True  (47660 lines)
# VAL_LIST  : True  (31770 lines)
# TEST_LIST : True  (15884 lines)

# %% [markdown]
# ### 3.4 Fix Degenerate GT Bboxes → `labels_fixed`

# %%
# Scan all .txt files, remove any line with bw < 1e-4 OR bh < 1e-4
# (same logic as project-phase1-vdt.ipynb Section 4.1)
LABELS_FIXED.mkdir(parents=True, exist_ok=True)
n_existing_fixed = len(list(LABELS_FIXED.glob("*.txt")))

if n_existing_fixed > 50_000:
    print(f"labels_fixed already built: {n_existing_fixed:,} files — skipping")
else:
    label_files = sorted(LABEL_DIR.glob("*.txt"))
    print(f"Fixing degenerate bboxes in {len(label_files):,} files...")

    n_files_touched = 0
    n_lines_removed = 0
    removed_log = []

    for lf in tqdm(label_files, desc="Fix degenerate", ncols=80):
        with open(lf) as f:
            lines = f.readlines()
        clean = []
        for line in lines:
            stripped = line.strip()
            if not stripped:
                clean.append(line)
                continue
            parts = stripped.split()
            if len(parts) != 5:
                clean.append(line)
                continue
            try:
                bw, bh = float(parts[3]), float(parts[4])
            except:
                clean.append(line)
                continue
            if bw < MIN_BBOX_DIM or bh < MIN_BBOX_DIM:
                n_lines_removed += 1
                removed_log.append(f"{lf.name}: bw={bw:.6f} bh={bh:.6f}")
            else:
                clean.append(line)
        out = LABELS_FIXED / lf.name
        with open(out, "w") as f:
            f.writelines(clean)
        if len(clean) != len(lines):
            n_files_touched += 1

    print(f"Files modified : {n_files_touched}")
    print(f"Lines removed  : {n_lines_removed}")
    for entry in removed_log:
        print(f"  {entry}")
    if n_lines_removed == 0:
        print("  (no degenerate boxes found)")
    print(f"labels_fixed   : {len(list(LABELS_FIXED.glob('*.txt'))):,} files")
# Out:
# Fixing degenerate bboxes in 95,314 files...
# Fix degenerate:   0%|                                 | 0/95314 [00:00<?, ?it/s]
# Files modified : 3
# Lines removed  : 3
#   bothFireAndSmoke_CV001979.txt: bw=0.000000 bh=0.002331
#   bothFireAndSmoke_CV010851.txt: bw=0.953750 bh=0.000000
#   bothFireAndSmoke_CV018145.txt: bw=0.000000 bh=0.454545
# labels_fixed   : 95,314 files

# %% [markdown]
# ## S4. Load GT Annotations

# %%
# Load all GT bboxes from labels_fixed
# Format: class_id cx cy bw bh (YOLO normalized)

all_img_paths = sorted(IMG_DIR.glob("*.jpg"))
print(f"Total images in dataset: {len(all_img_paths):,}")

active_label_dir = LABELS_FIXED if LABELS_FIXED.exists() else LABEL_DIR
print(f"Label source: {active_label_dir}")

img_ann_map = {}  # stem → [(cls_id, cx, cy, bw, bh), ...]
for p in tqdm(all_img_paths, desc="Loading GT", ncols=80):
    lbl = active_label_dir / (p.stem + ".txt")
    boxes = []
    if lbl.exists():
        for line in lbl.read_text().splitlines():
            parts = line.strip().split()
            if len(parts) == 5:
                try:
                    cls_id = int(parts[0])
                    cx, cy, bw, bh = map(float, parts[1:])
                    boxes.append((cls_id, cx, cy, bw, bh))
                except:
                    pass
    img_ann_map[p.stem] = boxes

ann_stems = [p.stem for p in all_img_paths if img_ann_map.get(p.stem)]
bg_stems  = [p.stem for p in all_img_paths if not img_ann_map.get(p.stem)]

n_fire  = sum(1 for v in img_ann_map.values() for b in v if b[0] == 0)
n_smoke = sum(1 for v in img_ann_map.values() for b in v if b[0] == 1)
print(f"Annotated images : {len(ann_stems):,}")
print(f"Background images: {len(bg_stems):,}")
print(f"Fire boxes       : {n_fire:,}")
print(f"Smoke boxes      : {n_smoke:,}")
# Out:
# Total images in dataset: 95,314
# Label source: /kaggle/working/labels_fixed
# Loading GT:   0%|                                     | 0/95314 [00:00<?, ?it/s]
# Annotated images : 56,115
# Background images: 39,199
# Fire boxes       : 73,295
# Smoke boxes      : 53,079

# %% [markdown]
# ## S5. Comprehensive EDA on Seg Masks
#
# ### 5.0 — Parse All Seg Files

# %%
# Parse all seg files and collect metrics per polygon line and per image
print("Parsing seg files from labels_seg_raw/ ...")

seg_records  = []   # one row per polygon line
cov_records  = []   # one row per annotated image
split_map    = {}   # stem → 'train'/'val'/'test'

for split_name, list_file in [("train", TRAIN_LIST), ("val", VAL_LIST), ("test", TEST_LIST)]:
    if list_file.exists():
        for line in open(list_file):
            stem = Path(line.strip()).stem
            split_map[stem] = split_name

# Helper: compute polygon area (shoelace, normalized)
def poly_area_normalized(coords):
    xs, ys = coords[0::2], coords[1::2]
    n = len(xs)
    if n < 3:
        return 0.0
    area = abs(sum(xs[i]*ys[i+1] - xs[i+1]*ys[i] for i in range(n-1)) +
               xs[-1]*ys[0] - xs[0]*ys[-1]) / 2
    return float(area)

for stem in tqdm(ann_stems, desc="Parsing", ncols=80):
    seg_file = LABELS_SEG_RAW / (stem + ".txt")
    gt_boxes = img_ann_map[stem]
    n_gt     = len(gt_boxes)
    split    = split_map.get(stem, "unknown")

    raw_lines = []
    if seg_file.exists() and seg_file.stat().st_size > 0:
        raw_lines = [l.strip() for l in seg_file.read_text().splitlines() if l.strip()]

    n_seg = len(raw_lines)
    line_counts = Counter(raw_lines)
    n_exact_dup  = sum(c - 1 for c in line_counts.values())   # extra copies

    # Coverage status
    if   n_seg == 0:       status = "empty"
    elif n_seg == n_gt:    status = "perfect"
    elif n_seg > n_gt:     status = "over"
    else:                  status = "partial"

    cov_records.append({
        "stem": stem, "n_gt": n_gt, "n_seg": n_seg,
        "n_exact_dup": n_exact_dup, "status": status,
        "has_file": seg_file.exists(), "split": split,
    })

    # Per-polygon metrics
    for line in raw_lines:
        parts  = line.split()
        n_tok  = len(parts)
        is_dup = line_counts[line] > 1

        try:
            cls_id = int(parts[0])
        except:
            cls_id = -1

        n_coords = n_tok - 1
        n_pts    = n_coords // 2

        # Validity checks
        is_degen = (n_tok < 7) or (n_coords % 2 != 0)   # < 3 points or odd coords

        coords_ok   = False
        poly_area   = 0.0
        inside_ratio = 0.0

        if not is_degen and cls_id >= 0:
            try:
                coords = list(map(float, parts[1:]))
                coords_ok = all(0.0 <= v <= 1.0 for v in coords)
                poly_area = poly_area_normalized(coords)

                # Inside ratio: polygon centroid vs nearest GT box of same class
                xs, ys = coords[0::2], coords[1::2]
                px, py = sum(xs)/len(xs), sum(ys)/len(ys)
                for b_cls, b_cx, b_cy, b_bw, b_bh in gt_boxes:
                    if b_cls == cls_id:
                        x1, y1 = b_cx - b_bw/2, b_cy - b_bh/2
                        x2, y2 = b_cx + b_bw/2, b_cy + b_bh/2
                        if x1 <= px <= x2 and y1 <= py <= y2:
                            inside_ratio = 1.0
                            break
            except:
                pass

        seg_records.append({
            "stem": stem, "split": split, "cls_id": cls_id,
            "n_pts": n_pts, "is_degenerate": is_degen,
            "coords_ok": coords_ok, "poly_area": poly_area,
            "is_dup": is_dup, "inside_ratio": inside_ratio,
        })

df_seg = pd.DataFrame(seg_records)
df_cov = pd.DataFrame(cov_records)

print(f"Parsed {len(df_seg):,} polygon lines from {len(df_cov):,} annotated images.")
# Out:
# Parsing seg files from labels_seg_raw/ ...
# Parsing:   0%|                                        | 0/56115 [00:00<?, ?it/s]
# Parsed 126,228 polygon lines from 56,115 annotated images.

# %% [markdown]
# ### 5.1 — Dataset-Level Statistics

# %%
print("=" * 65)
print("S5.1 — DATASET-LEVEL STATISTICS")
print("=" * 65)

n_ann    = len(ann_stems)
n_total  = len(all_img_paths)
n_seg_files = df_cov["has_file"].sum()
n_tot_gt    = df_cov["n_gt"].sum()
n_tot_seg   = df_cov["n_seg"].sum()

print(f"Total images                    : {n_total:,}")
print(f"  Annotated (has GT boxes)      : {n_ann:,}  ({n_ann/n_total*100:.1f}%)")
print(f"  Background (no GT)            : {len(bg_stems):,}")
print()
print(f"Seg files present               : {n_seg_files:,}  ({n_seg_files/n_ann*100:.1f}% of annotated)")
print(f"Seg files missing               : {n_ann - n_seg_files:,}")
print()
print(f"Total GT boxes                  : {n_tot_gt:,}")
print(f"Total seg polygon lines         : {n_tot_seg:,}  ({n_tot_seg/max(1,n_tot_gt)*100:.1f}% of GT)")
print()
print(f"Polygon quality:")
n_degen  = df_seg["is_degenerate"].sum()
n_oor    = (~df_seg["coords_ok"] & ~df_seg["is_degenerate"]).sum()
n_dup    = df_seg["is_dup"].sum()
n_good   = len(df_seg) - n_degen - n_oor
print(f"  Degenerate (< 3 pts OR odd)   : {n_degen:,}  ({n_degen/max(1,len(df_seg))*100:.2f}%)")
print(f"  Coords out-of-range [0,1]     : {n_oor:,}  ({n_oor/max(1,len(df_seg))*100:.2f}%)")
print(f"  Exact duplicates (extra copy) : {n_dup:,}  ({n_dup/max(1,len(df_seg))*100:.2f}%)")
print(f"  Good polygons                 : {n_good:,}  ({n_good/max(1,len(df_seg))*100:.2f}%)")
print()

status_counts = df_cov["status"].value_counts()
print("Coverage status (images):")
for s, c in status_counts.items():
    print(f"  {s:<10}: {c:,}  ({c/n_ann*100:.1f}%)")
# Out:
# =================================================================
# S5.1 — DATASET-LEVEL STATISTICS
# =================================================================
# Total images                    : 95,314
#   Annotated (has GT boxes)      : 56,115  (58.9%)
#   Background (no GT)            : 39,199
#
# Seg files present               : 56,086  (99.9% of annotated)
# Seg files missing               : 29
#
# Total GT boxes                  : 126,374
# Total seg polygon lines         : 126,228  (99.9% of GT)
#
# Polygon quality:
#   Degenerate (< 3 pts OR odd)   : 0  (0.00%)
#   Coords out-of-range [0,1]     : 0  (0.00%)
#   Exact duplicates (extra copy) : 60  (0.05%)
#   Good polygons                 : 126,228  (100.00%)
#
# Coverage status (images):
#   perfect   : 55,999  (99.8%)
#   partial   : 86  (0.2%)
#   empty     : 29  (0.1%)
#   over      : 1  (0.0%)

# %% [markdown]
# ### 5.2 — Coverage Audit + Duplicate Analysis Plots

# %%
fig, axes = plt.subplots(2, 3, figsize=(18, 10))
fig.suptitle("S5.2 — Seg Coverage Audit & Duplicate Analysis", fontsize=13, fontweight="bold")
axes = axes.ravel()

STATUS_COLORS = {
    "perfect": "#27ae60", "partial": "#f39c12",
    "empty":   "#e74c3c", "over":    "#9b59b6"
}
STATUS_ORDER = ["perfect", "partial", "empty", "over"]

# ── [0] Coverage status bar ───────────────────────────────────────────────────
ax = axes[0]
sc = df_cov["status"].value_counts().reindex(STATUS_ORDER, fill_value=0)
bars = ax.bar(sc.index, sc.values,
              color=[STATUS_COLORS[k] for k in sc.index], edgecolor="white", lw=0.8)
ax.set_title("Images by Coverage Status")
ax.set_ylabel("# images")
for bar, v in zip(bars, sc.values):
    pct = v / n_ann * 100
    ax.text(bar.get_x() + bar.get_width()/2, bar.get_height() + 50,
            f"{v:,}\n({pct:.1f}%)", ha="center", va="bottom", fontsize=8)
patches = [mpatches.Patch(color=STATUS_COLORS[s], label=s) for s in STATUS_ORDER]
ax.legend(handles=patches, fontsize=7)

# ── [1] n_seg / n_gt ratio histogram ─────────────────────────────────────────
ax = axes[1]
df_ann_cov = df_cov[df_cov["n_gt"] > 0]
ratios = (df_ann_cov["n_seg"] / df_ann_cov["n_gt"]).clip(upper=2.5)
ax.hist(ratios, bins=50, color="#3498db", edgecolor="white", alpha=0.85)
ax.axvline(1.0, color="red", lw=2, ls="--", label="perfect (ratio=1.0)")
ax.set_title("n_seg / n_gt per image")
ax.set_xlabel("ratio  (clipped at 2.5)")
ax.set_ylabel("# images")
ax.legend(fontsize=8)

# ── [2] Images with exact duplicate lines ─────────────────────────────────────
ax = axes[2]
n_has_dup = (df_cov["n_exact_dup"] > 0).sum()
n_no_dup  = n_ann - n_has_dup
bars2 = ax.bar(["No duplicates", "Has duplicates"], [n_no_dup, n_has_dup],
               color=["#27ae60", "#e74c3c"], edgecolor="white")
ax.set_title("Files with exact duplicate polygon lines")
ax.set_ylabel("# images")
for bar, v in zip(bars2, [n_no_dup, n_has_dup]):
    ax.text(bar.get_x() + bar.get_width()/2, bar.get_height() + 10,
            f"{v:,}\n({v/n_ann*100:.1f}%)", ha="center", va="bottom", fontsize=9)

# ── [3] Distribution of total duplicate count per file ────────────────────────
ax = axes[3]
dup_counts = df_cov[df_cov["n_exact_dup"] > 0]["n_exact_dup"]
if len(dup_counts) > 0:
    ax.hist(dup_counts.clip(upper=10), bins=range(1, 12), color="#e74c3c",
            edgecolor="white", alpha=0.85, rwidth=0.85)
    ax.set_title("Duplicate line count per file\n(among files with duplicates)")
    ax.set_xlabel("# duplicate lines (clipped at 10)")
    ax.set_ylabel("# files")
    ax.set_xticks(range(1, 11))
else:
    ax.text(0.5, 0.5, "No duplicates found!", transform=ax.transAxes,
            ha="center", va="center", fontsize=12, color="green")
    ax.set_title("Duplicate line count per file")

# ── [4] n_gt_boxes per image distribution ────────────────────────────────────
ax = axes[4]
gt_counts = df_cov["n_gt"].clip(upper=10)
ax.hist(gt_counts, bins=range(1, 12), color="#2ecc71", edgecolor="white",
        alpha=0.85, rwidth=0.85)
ax.set_title("GT boxes per annotated image")
ax.set_xlabel("# GT boxes (clipped at 10)")
ax.set_ylabel("# images")
ax.set_xticks(range(1, 11))

# ── [5] Over-masked images: n_seg - n_gt ─────────────────────────────────────
ax = axes[5]
over_df = df_cov[df_cov["status"] == "over"]
if len(over_df) > 0:
    excess = (over_df["n_seg"] - over_df["n_gt"]).clip(upper=10)
    ax.hist(excess, bins=range(1, 12), color="#9b59b6", edgecolor="white",
            alpha=0.85, rwidth=0.85)
    ax.set_title(f"Over-masked: excess seg lines\n({len(over_df):,} images with n_seg > n_gt)")
    ax.set_xlabel("# excess seg lines (clipped at 10)")
    ax.set_ylabel("# files")
    ax.set_xticks(range(1, 11))
else:
    ax.text(0.5, 0.5, "No over-masked images!", transform=ax.transAxes,
            ha="center", va="center", fontsize=12, color="green")
    ax.set_title("Over-masked: excess seg lines")

plt.tight_layout()
plt.savefig(WORK_DIR / "eda_s52_coverage.png", dpi=130, bbox_inches="tight")
plt.show()
print(f"Saved: eda_s52_coverage.png")
# Out:
# Saved: eda_s52_coverage.png

# %% [markdown]
# ### 5.3 — Polygon Quality Check (Degenerate & Out-of-Range)

# %%
print("=" * 65)
print("S5.3 — POLYGON QUALITY CHECK")
print("=" * 65)

# Degenerate detail
degen_df = df_seg[df_seg["is_degenerate"]]
print(f"Degenerate polygons: {len(degen_df):,}")
if len(degen_df) > 0:
    print("  Breakdown:")
    print(f"    cls_id distribution : {dict(degen_df['cls_id'].value_counts())}")
    print(f"    n_pts distribution  : {dict(degen_df['n_pts'].value_counts().head(8))}")
    # Show examples
    degen_samples = degen_df.head(5)["stem"].tolist()
    print("  Example stems:", degen_samples[:3])

# Out-of-range coords (non-degenerate polygons with coords outside [0,1])
oor_df = df_seg[~df_seg["is_degenerate"] & ~df_seg["coords_ok"]]
print(f"\nOut-of-range coords: {len(oor_df):,}")
if len(oor_df) > 0:
    print("  Example stems:", oor_df.head(3)["stem"].tolist())

# Good polygons
good_df = df_seg[~df_seg["is_degenerate"] & df_seg["coords_ok"]]
print(f"\nGood polygons: {len(good_df):,}  ({len(good_df)/max(1,len(df_seg))*100:.2f}%)")
print(f"  Fire (cls=0) : {(good_df['cls_id']==0).sum():,}")
print(f"  Smoke (cls=1): {(good_df['cls_id']==1).sum():,}")
# Out:
# =================================================================
# S5.3 — POLYGON QUALITY CHECK
# =================================================================
# Degenerate polygons: 0
#
# Out-of-range coords: 0
#
# Good polygons: 126,228  (100.00%)
#   Fire (cls=0) : 73,191
#   Smoke (cls=1): 53,037

# %% [markdown]
# ### 5.4 — Mask Area & Polygon Point Count Distributions

# %%
good = df_seg[~df_seg["is_degenerate"] & df_seg["coords_ok"]]

fig, axes = plt.subplots(2, 2, figsize=(15, 10))
fig.suptitle("S5.4 — Polygon Geometry Distributions", fontsize=13, fontweight="bold")
axes = axes.ravel()

cls_colors = {0: "#e74c3c", 1: "#3498db"}
cls_names  = {0: "fire", 1: "smoke"}

# ── [0] Polygon area distribution (log-scale) ─────────────────────────────────
ax = axes[0]
for cls_id in [0, 1]:
    subset = good[good["cls_id"] == cls_id]["poly_area"]
    if len(subset) > 0:
        ax.hist(subset.clip(upper=0.5), bins=60, alpha=0.6,
                color=cls_colors[cls_id], label=cls_names[cls_id],
                edgecolor="none", density=True)
ax.set_title("Polygon Area Distribution (normalized, clipped at 0.5)")
ax.set_xlabel("area (fraction of image)")
ax.set_ylabel("density")
ax.legend(fontsize=9)

# ── [1] Polygon area (log-scale) ──────────────────────────────────────────────
ax = axes[1]
for cls_id in [0, 1]:
    subset = good[good["cls_id"] == cls_id]["poly_area"].clip(lower=1e-6)
    if len(subset) > 0:
        ax.hist(np.log10(subset), bins=60, alpha=0.6,
                color=cls_colors[cls_id], label=cls_names[cls_id],
                edgecolor="none", density=True)
ax.set_title("Polygon Area — log₁₀ scale")
ax.set_xlabel("log₁₀(area)")
ax.set_ylabel("density")
ax.legend(fontsize=9)

# ── [2] Polygon point count distribution ──────────────────────────────────────
ax = axes[2]
for cls_id in [0, 1]:
    subset = good[good["cls_id"] == cls_id]["n_pts"].clip(upper=100)
    if len(subset) > 0:
        ax.hist(subset, bins=50, alpha=0.6,
                color=cls_colors[cls_id], label=cls_names[cls_id], edgecolor="none")
ax.axvline(MIN_SEG_POINTS, color="red", ls="--", lw=1.5, label=f"min={MIN_SEG_POINTS}")
ax.set_title("Polygon Point Count Distribution")
ax.set_xlabel("# points per polygon (clipped at 100)")
ax.set_ylabel("# polygons")
ax.legend(fontsize=9)

# ── [3] Polygon point count CDF ───────────────────────────────────────────────
ax = axes[3]
for cls_id in [0, 1]:
    subset = good[good["cls_id"] == cls_id]["n_pts"].sort_values()
    if len(subset) > 0:
        ax.plot(subset.values, np.linspace(0, 1, len(subset)),
                color=cls_colors[cls_id], label=cls_names[cls_id], lw=2)
ax.set_title("Polygon Points — CDF")
ax.set_xlabel("# points")
ax.set_ylabel("cumulative fraction")
ax.set_xlim(0, 80)
ax.legend(fontsize=9)
ax.grid(alpha=0.3)

plt.tight_layout()
plt.savefig(WORK_DIR / "eda_s54_geometry.png", dpi=130, bbox_inches="tight")
plt.show()

print("Polygon point count stats:")
for cls_id in [0, 1]:
    s = good[good["cls_id"] == cls_id]["n_pts"]
    if len(s) > 0:
        print(f"  {cls_names[cls_id]}: mean={s.mean():.1f}  median={s.median():.0f}  "
              f"p5={s.quantile(0.05):.0f}  p95={s.quantile(0.95):.0f}  max={s.max()}")
# Out:
# Polygon point count stats:
#   fire: mean=23.0  median=23  p5=13  p95=34  max=55
#   smoke: mean=23.6  median=23  p5=14  p95=34  max=53

# %% [markdown]
# ### 5.5 — Per-Class & Train/Val/Test Split Breakdown

# %%
print("=" * 65)
print("S5.5 — PER-CLASS & SPLIT BREAKDOWN")
print("=" * 65)

# Per-class GT vs Seg counts
for cls_id, cls_name in [(0, "fire"), (1, "smoke")]:
    n_gt_cls  = sum(1 for v in img_ann_map.values() for b in v if b[0] == cls_id)
    n_seg_cls = (df_seg["cls_id"] == cls_id).sum()
    n_good_cls = ((df_seg["cls_id"] == cls_id) &
                  ~df_seg["is_degenerate"] & df_seg["coords_ok"]).sum()
    print(f"  {cls_name:5s}: GT={n_gt_cls:,}  seg_lines={n_seg_cls:,}  "
          f"good={n_good_cls:,}  coverage={n_seg_cls/max(1,n_gt_cls)*100:.1f}%")

print()

# Per-split summary
fig, axes = plt.subplots(1, 3, figsize=(16, 5))
fig.suptitle("S5.5 — Coverage by Split", fontsize=12, fontweight="bold")

for ax_idx, split_name in enumerate(["train", "val", "test"]):
    ax = axes[ax_idx]
    split_df = df_cov[df_cov["split"] == split_name]
    if len(split_df) == 0:
        ax.text(0.5, 0.5, f"No {split_name} data", transform=ax.transAxes,
                ha="center", va="center")
        continue

    sc = split_df["status"].value_counts().reindex(STATUS_ORDER, fill_value=0)
    bars = ax.bar(sc.index, sc.values,
                  color=[STATUS_COLORS[k] for k in sc.index], edgecolor="white")
    ax.set_title(f"{split_name}  ({len(split_df):,} images)")
    ax.set_ylabel("# images")
    n_ann_split = len(split_df)
    for bar, v in zip(bars, sc.values):
        ax.text(bar.get_x() + bar.get_width()/2, bar.get_height() + max(5, n_ann_split*0.005),
                f"{v:,}\n({v/n_ann_split*100:.1f}%)",
                ha="center", va="bottom", fontsize=7)

    n_gt_s  = split_df["n_gt"].sum()
    n_seg_s = split_df["n_seg"].sum()
    ax.set_xlabel(f"GT={n_gt_s:,}  Seg={n_seg_s:,}  ({n_seg_s/max(1,n_gt_s)*100:.1f}%)")

plt.tight_layout()
plt.savefig(WORK_DIR / "eda_s55_split.png", dpi=130, bbox_inches="tight")
plt.show()

# Print table
print(f"{'Split':<10} {'n_img':>7} {'n_gt':>8} {'n_seg':>8} {'pct':>6} {'perfect':>8} {'empty':>7} {'over':>6}")
for s in ["train", "val", "test"]:
    sdf = df_cov[df_cov["split"] == s]
    if len(sdf) == 0: continue
    ng = sdf["n_gt"].sum(); ns = sdf["n_seg"].sum()
    n_perf  = (sdf["status"]=="perfect").sum()
    n_empty = (sdf["status"]=="empty").sum()
    n_over  = (sdf["status"]=="over").sum()
    print(f"{s:<10} {len(sdf):>7,} {ng:>8,} {ns:>8,} {ns/max(1,ng)*100:>5.1f}% "
          f"{n_perf:>8,} {n_empty:>7,} {n_over:>6,}")
# Out:
# =================================================================
# S5.5 — PER-CLASS & SPLIT BREAKDOWN
# =================================================================
#   fire : GT=73,295  seg_lines=73,191  good=73,191  coverage=99.9%
#   smoke: GT=53,079  seg_lines=53,037  good=53,037  coverage=99.9%
# Split        n_img     n_gt    n_seg    pct  perfect   empty   over
# train       28,060   66,580   66,501  99.9%   27,995      13      1
# val         18,704   42,552   42,507  99.9%   18,668       8      0
# test         9,351   17,242   17,220  99.9%    9,336       8      0

# %% [markdown]
# ### 5.6 — Visual Spot-Check (16 Random Samples with Masks)

# %%
# 16-image grid: 4 rows (perfect / partial / empty / over) × 4 cols
def yolo_to_pixel(cx, cy, bw, bh, W, H):
    x1 = int((cx - bw/2) * W); y1 = int((cy - bh/2) * H)
    x2 = int((cx + bw/2) * W); y2 = int((cy + bh/2) * H)
    return max(0,x1), max(0,y1), min(W,x2), min(H,y2)

def draw_seg_overlay(img_rgb, seg_file, gt_boxes, img_w, img_h):
    vis = img_rgb.copy()
    cls_fill = {0: (255, 80, 0), 1: (30, 120, 255)}
    if seg_file.exists() and seg_file.stat().st_size > 0:
        for line in seg_file.read_text().splitlines():
            parts = line.strip().split()
            if len(parts) < 7: continue
            try:
                cls_id = int(parts[0])
                pts = np.array(list(map(float, parts[1:]))).reshape(-1, 2)
                pts[:, 0] *= img_w; pts[:, 1] *= img_h
                pts = pts.astype(np.int32).reshape(-1, 1, 2)
                c = cls_fill.get(cls_id, (200, 200, 200))
                ov = vis.copy()
                cv2.fillPoly(ov, [pts], c)
                vis = cv2.addWeighted(vis, 0.55, ov, 0.45, 0)
                cv2.polylines(vis, [pts], True, c, 2)
            except: pass
    for cls_id, cx, cy, bw, bh in gt_boxes:
        x1,y1,x2,y2 = yolo_to_pixel(cx, cy, bw, bh, img_w, img_h)
        cv2.rectangle(vis, (x1,y1), (x2,y2), (0,255,0), 2)
    return vis

n_per_status = 4
sample_stems_by_status = {}
for s in ["perfect", "partial", "empty", "over"]:
    pool = df_cov[df_cov["status"] == s]["stem"].tolist()
    sample_stems_by_status[s] = random.sample(pool, min(n_per_status, len(pool)))

fig, axes = plt.subplots(4, 4, figsize=(16, 16))
fig.suptitle(
    "S5.6 — Visual Spot-Check  |  Green bbox = GT  |  Colored fill = Seg mask\n"
    "Row: perfect / partial / empty / over",
    fontsize=10)

for row_idx, s in enumerate(["perfect", "partial", "empty", "over"]):
    stems = sample_stems_by_status.get(s, [])
    for col_idx in range(4):
        ax = axes[row_idx][col_idx]
        ax.axis("off")
        if col_idx >= len(stems): continue
        stem = stems[col_idx]
        img_path = IMG_DIR / (stem + ".jpg")
        img_cv = cv2.imread(str(img_path))
        if img_cv is None: continue
        H, W = img_cv.shape[:2]
        img_rgb = cv2.cvtColor(img_cv, cv2.COLOR_BGR2RGB)
        vis = draw_seg_overlay(img_rgb, LABELS_SEG_RAW / (stem + ".txt"),
                               img_ann_map[stem], W, H)
        row_info = df_cov[df_cov["stem"] == stem].iloc[0]
        ax.imshow(vis)
        ax.set_title(f"[{s}] GT={int(row_info.n_gt)} Seg={int(row_info.n_seg)}",
                     fontsize=7, pad=2)

plt.tight_layout()
plt.savefig(WORK_DIR / "eda_s56_visual.png", dpi=130, bbox_inches="tight")
plt.show()
print("Saved: eda_s56_visual.png")
# Out:
# Saved: eda_s56_visual.png

# %% [markdown]
# ## S6. Preprocessing → `labels_seg_clean`
#
# Three steps:
# 1. Remove exact duplicate polygon lines within each file
# 2. Remove degenerate polygons (< 3 points, odd coord count, out-of-range)
# 3. Deduplicate image paths in train/val/test `.txt` files (prevent YOLO dup warnings)

# %%
# =============================================================================
#  S6.1 — Clean Seg Labels → labels_seg_clean/
# =============================================================================
print("Cleaning seg labels...")
LABELS_SEG_CLEAN.mkdir(parents=True, exist_ok=True)

stats = {
    "files_written": 0, "lines_in": 0, "lines_out": 0,
    "removed_dup": 0, "removed_degen": 0, "removed_oor": 0,
}

for stem in tqdm(ann_stems, desc="Cleaning", ncols=80):
    seg_file = LABELS_SEG_RAW / (stem + ".txt")

    raw_lines = []
    if seg_file.exists() and seg_file.stat().st_size > 0:
        raw_lines = [l.strip() for l in seg_file.read_text().splitlines() if l.strip()]

    stats["lines_in"] += len(raw_lines)

    seen       = set()   # exact dedup
    clean_lines = []

    for line in raw_lines:
        # Step 1: exact duplicate
        if line in seen:
            stats["removed_dup"] += 1
            continue
        seen.add(line)

        parts  = line.split()
        n_tok  = len(parts)
        n_crd  = n_tok - 1

        # Step 2: degenerate (< 3 points OR odd coord count)
        if n_tok < 7 or n_crd % 2 != 0:
            stats["removed_degen"] += 1
            continue

        # Step 3: out-of-range coordinates
        try:
            coords = list(map(float, parts[1:]))
        except:
            stats["removed_degen"] += 1
            continue

        if not all(0.0 <= v <= 1.0 for v in coords):
            # Clamp instead of discard (minor overshoots at boundary)
            clamped = [round(max(0.0, min(1.0, v)), 6) for v in coords]
            try:
                cls_id = int(parts[0])
            except:
                stats["removed_oor"] += 1
                continue
            line = str(cls_id) + " " + " ".join(f"{v:.6f}" for v in clamped)
            stats["removed_oor"] += 1   # counted as fixed (still kept)

        clean_lines.append(line)

    stats["lines_out"] += len(clean_lines)
    out_path = LABELS_SEG_CLEAN / (stem + ".txt")
    out_path.write_text("\n".join(clean_lines) + ("\n" if clean_lines else ""))
    stats["files_written"] += 1

print()
print("=" * 55)
print("S6.1 — Cleaning Summary")
print("=" * 55)
print(f"  Files written          : {stats['files_written']:,}")
print(f"  Lines in (raw)         : {stats['lines_in']:,}")
print(f"  Removed exact dup      : {stats['removed_dup']:,}")
print(f"  Removed degenerate     : {stats['removed_degen']:,}")
print(f"  Coords clamped/fixed   : {stats['removed_oor']:,}")
print(f"  Lines out (clean)      : {stats['lines_out']:,}")
print(f"  Net reduction          : {stats['lines_in'] - stats['lines_out']:,}  "
      f"({(1 - stats['lines_out']/max(1,stats['lines_in']))*100:.2f}%)")
# Out:
# Cleaning seg labels...
# Cleaning:   0%|                                       | 0/56115 [00:00<?, ?it/s]
# =======================================================
# S6.1 — Cleaning Summary
# =======================================================
#   Files written          : 56,115
#   Lines in (raw)         : 126,228
#   Removed exact dup      : 30
#   Removed degenerate     : 0
#   Coords clamped/fixed   : 0
#   Lines out (clean)      : 126,198
#   Net reduction          : 30  (0.02%)

# %%
# =============================================================================
#  S6.2 — Deduplicate Image Lists (prevent YOLO dup warnings)
# =============================================================================
print("\nDeduplicating image split lists...")

for list_file in [TRAIN_LIST, VAL_LIST, TEST_LIST]:
    if not list_file.exists():
        continue
    original = [l.strip() for l in open(list_file) if l.strip()]
    deduped  = list(dict.fromkeys(original))  # preserve order
    n_removed = len(original) - len(deduped)
    if n_removed > 0:
        with open(list_file, "w") as f:
            f.write("\n".join(deduped) + "\n")
        print(f"  {list_file.name}: removed {n_removed} duplicate paths")
    else:
        print(f"  {list_file.name}: no duplicates  ({len(deduped):,} paths)")

# Cross-split overlap check (images appearing in both train and val)
train_set = set(Path(l.strip()).stem for l in open(TRAIN_LIST) if l.strip())
val_set   = set(Path(l.strip()).stem for l in open(VAL_LIST)   if l.strip())
test_set  = set(Path(l.strip()).stem for l in open(TEST_LIST)  if l.strip())

tv_overlap = train_set & val_set
tt_overlap = train_set & test_set
vt_overlap = val_set   & test_set

print(f"\nCross-split overlap:")
print(f"  train ∩ val  : {len(tv_overlap):,}  {'⚠️ LEAK' if tv_overlap else '✓'}")
print(f"  train ∩ test : {len(tt_overlap):,}  {'⚠️ LEAK' if tt_overlap else '✓'}")
print(f"  val ∩ test   : {len(vt_overlap):,}  {'⚠️ LEAK' if vt_overlap else '✓'}")
# Out:
# Deduplicating image split lists...
#   train_images.txt: no duplicates  (47,660 paths)
#   val_images.txt: no duplicates  (31,770 paths)
#   test_images.txt: no duplicates  (15,884 paths)
#
# Cross-split overlap:
#   train ∩ val  : 0  ✓
#   train ∩ test : 0  ✓
#   val ∩ test   : 0  ✓

# %%
# =============================================================================
#  S6.3 — (Optional) BBox Rectangle Fallback for Images with No Seg Labels
# =============================================================================
if BBOX_FALLBACK_FOR_MISSING:
    print("\nS6.3 — BBox fallback for images with no seg labels...")

    def bbox_to_rect_polygon(cx, cy, bw, bh):
        """YOLO bbox → 4-corner rectangle polygon (normalized coords)."""
        x1, y1 = max(0.0, cx - bw/2), max(0.0, cy - bh/2)
        x2, y2 = min(1.0, cx + bw/2), min(1.0, cy + bh/2)
        return [x1, y1, x2, y1, x2, y2, x1, y2]

    n_fallback = 0
    for stem in tqdm(ann_stems, desc="Fallback", ncols=80):
        clean_file = LABELS_SEG_CLEAN / (stem + ".txt")
        if clean_file.exists() and clean_file.stat().st_size > 0:
            continue  # already has seg labels
        gt_boxes = img_ann_map.get(stem, [])
        if not gt_boxes:
            continue
        lines = []
        for cls_id, cx, cy, bw, bh in gt_boxes:
            pts = bbox_to_rect_polygon(cx, cy, bw, bh)
            line = str(cls_id) + " " + " ".join(f"{v:.6f}" for v in pts)
            lines.append(line)
        clean_file.write_text("\n".join(lines) + "\n")
        n_fallback += 1

    print(f"  Bbox fallback applied to {n_fallback:,} images")
else:
    print("S6.3 — BBox fallback DISABLED (BBOX_FALLBACK_FOR_MISSING=False)")
# Out:
# S6.3 — BBox fallback DISABLED (BBOX_FALLBACK_FOR_MISSING=False)

# %%
# =============================================================================
#  S6.4 — Post-Clean Statistics
# =============================================================================
print("\n" + "=" * 65)
print("S6.4 — POST-CLEAN STATISTICS")
print("=" * 65)

cov_after = []
for stem in ann_stems:
    clean_file = LABELS_SEG_CLEAN / (stem + ".txt")
    gt_boxes   = img_ann_map[stem]
    n_gt       = len(gt_boxes)
    n_seg      = 0
    if clean_file.exists() and clean_file.stat().st_size > 0:
        n_seg = sum(1 for l in clean_file.read_text().splitlines() if l.strip())
    status = ("perfect" if n_seg == n_gt else
              "over"    if n_seg > n_gt  else
              "empty"   if n_seg == 0   else "partial")
    cov_after.append({"stem": stem, "n_gt": n_gt, "n_seg": n_seg, "status": status})

df_after = pd.DataFrame(cov_after)
n_tot_after = df_after["n_seg"].sum()
n_tot_gt    = df_after["n_gt"].sum()

print(f"Clean seg files  : {len(list(LABELS_SEG_CLEAN.glob('*.txt'))):,}")
print(f"Total clean lines: {n_tot_after:,}  ({n_tot_after/max(1,n_tot_gt)*100:.1f}% of GT boxes)")
print()
print("Coverage status (after cleaning):")
sc_after = df_after["status"].value_counts().reindex(STATUS_ORDER, fill_value=0)
for s, c in sc_after.items():
    diff_key = s
    before_c = df_cov["status"].value_counts().get(s, 0)
    delta = c - before_c
    delta_str = f"  (Δ{delta:+d})" if delta != 0 else ""
    print(f"  {s:<10}: {c:,}  ({c/n_ann*100:.1f}%){delta_str}")

print()
print(f"Removed by cleaning:")
print(f"  Exact duplicates   : {stats['removed_dup']:,}")
print(f"  Degenerate polygons: {stats['removed_degen']:,}")
print(f"  Total net removed  : {stats['lines_in'] - stats['lines_out']:,}")
print()
print("✓ labels_seg_clean/ ready for training.")
# Out:
# =================================================================
# S6.4 — POST-CLEAN STATISTICS
# =================================================================
# Clean seg files  : 56,115
# Total clean lines: 126,198  (99.9% of GT boxes)
#
# Coverage status (after cleaning):
#   perfect   : 55,970  (99.7%)  (Δ-29)
#   partial   : 115  (0.2%)  (Δ+29)
#   empty     : 29  (0.1%)
#   over      : 1  (0.0%)
#
# Removed by cleaning:
#   Exact duplicates   : 30
#   Degenerate polygons: 0
#   Total net removed  : 30
#
# ✓ labels_seg_clean/ ready for training.

# %% [markdown]
# ## S7. Build YAML + Symlinks for Seg Training

# %%
# ── Symlinks ─────────────────────────────────────────────────────────────────
# /kaggle/working/images/ → actual images dir (read-only Kaggle input)
# /kaggle/working/labels/ → labels_seg_clean (our cleaned seg labels)
# YOLO derives label path: img_path.replace('/images/', '/labels/')

for link, target in [
    (WORKING_IMAGES, IMG_DIR),
    (WORKING_LABELS, LABELS_SEG_CLEAN),
]:
    if link.exists() or link.is_symlink():
        link.unlink()
    link.symlink_to(target)
    print(f"Symlink: {link.name} → {target}")

# Verify symlinks
print(f"\n  images/ → {WORKING_IMAGES.resolve()}")
print(f"  labels/ → {WORKING_LABELS.resolve()}")

# Quick sanity check: pick first train image and resolve its label
sample_line = open(TRAIN_LIST).readline().strip()
sample_img  = Path(sample_line)
sample_lbl  = Path(str(sample_img).replace("/images/", "/labels/")).with_suffix(".txt")
print(f"\nSanity check:")
print(f"  img: {sample_img}  exists={sample_img.exists()}")
print(f"  lbl: {sample_lbl}  exists={sample_lbl.exists()}")
# Out:
# Symlink: images → /kaggle/input/datasets/ctcaothanhbang/dataset-v2/FASDD_CV/FASDD_CV/images
# Symlink: labels → /kaggle/working/labels_seg_clean
#
#   images/ → /kaggle/input/datasets/ctcaothanhbang/dataset-v2/FASDD_CV/FASDD_CV/images
#   labels/ → /kaggle/working/labels_seg_clean
#
# Sanity check:
#   img: /kaggle/working/images/fire_CV006443.jpg  exists=True
#   lbl: /kaggle/working/labels/fire_CV006443.txt  exists=True

# %%
# ── data YAML ─────────────────────────────────────────────────────────────────
import yaml

data_cfg = {
    "path"  : str(WORK_DIR),
    "train" : str(TRAIN_LIST),
    "val"   : str(VAL_LIST),
    "test"  : str(TEST_LIST),
    "nc"    : 2,
    "names" : {0: "fire", 1: "smoke"},
}

with open(YAML_PATH, "w") as f:
    yaml.dump(data_cfg, f, default_flow_style=False, sort_keys=False)

print(f"YAML written: {YAML_PATH}")
print()
print(open(YAML_PATH).read())

# Validate first 5 label files via YAML resolution
print("Label path validation (first 5 train images):")
lines = open(TRAIN_LIST).readlines()[:5]
for line in lines:
    img_p = Path(line.strip())
    lbl_p = Path(str(img_p).replace("/images/", "/labels/")).with_suffix(".txt")
    n_lines = sum(1 for _ in open(lbl_p)) if lbl_p.exists() else 0
    print(f"  img_exists={img_p.exists()}  lbl_exists={lbl_p.exists()}  lbl_lines={n_lines}  → {lbl_p.name}")
# Out:
# YAML written: /kaggle/working/fasdd_cv_seg.yaml
#
# path: /kaggle/working
# train: /kaggle/working/train_images.txt
# val: /kaggle/working/val_images.txt
# test: /kaggle/working/test_images.txt
# nc: 2
# names:
#   0: fire
#   1: smoke
#
# Label path validation (first 5 train images):
#   img_exists=True  lbl_exists=True  lbl_lines=1  → fire_CV006443.txt
#   img_exists=True  lbl_exists=True  lbl_lines=1  → smoke_CV007439.txt
#   img_exists=True  lbl_exists=True  lbl_lines=3  → bothFireAndSmoke_CV003139.txt
#   img_exists=True  lbl_exists=True  lbl_lines=1  → smoke_CV019260.txt
#   img_exists=True  lbl_exists=False  lbl_lines=0  → neitherFireNorSmoke_CV028260.txt

# %% [markdown]
# ## S8. YOLO11m-seg Resume/Fresh Training
#
# Run **S0 → S7 first** every Kaggle session.
# If `RESUME_TRAINING=True`, this section copies the previous run directory from `/kaggle/input` into `/kaggle/working/fasdd_cv/...`, verifies `weights/last.pt`, patches `args.yaml` to point to the current `fasdd_cv_seg.yaml`, then calls:
#
# ```python
# YOLO(str(last_pt)).train(resume=True)
# ```
#
# Use `last.pt` for resume. Use `best.pt` only for evaluation/export.

# %%
# Save run config snapshot (Layer 2) BEFORE training/resume
CONFIG_PATH = save_run_config(RUN_DIR, extra={
    "labels_seg_raw_count"  : len(list(LABELS_SEG_RAW.glob("*.txt"))),
    "labels_seg_clean_count": len(list(LABELS_SEG_CLEAN.glob("*.txt"))),
    "clean_removed_dup"     : stats["removed_dup"],
    "clean_removed_degen"   : stats["removed_degen"],
    "resume_training"       : RESUME_TRAINING,
    "resume_run_input"      : str(RESUME_RUN_INPUT) if RESUME_TRAINING else None,
    "resume_last_pt_input"  : str(RESUME_LAST_PT) if RESUME_TRAINING else None,
})
# Out:
# Config snapshot → /kaggle/working/fasdd_cv/yolo11m_seg_finetune_imgsz1024_20260613-2/run_config.json

# %%
from ultralytics import YOLO
import torch, shutil, os, yaml
from pathlib import Path

device_str = "0,1" if USE_MULTI_GPU and torch.cuda.device_count() > 1 else ("0" if torch.cuda.is_available() else "cpu")

print("=" * 70)
print("Training mode")
print("=" * 70)
print(f"  Resume training : {RESUME_TRAINING}")
print(f"  Device          : {device_str}")
print(f"  YAML            : {YAML_PATH}")
print(f"  Run name        : {RUN_NAME}")
print(f"  Run dir         : {RUN_DIR}")
print("=" * 70)

# Keep wandb run name aligned with our run folder.
if WANDB_ENABLED:
    os.environ["WANDB_RUN_NAME"] = RUN_NAME

def patch_args_yaml(args_yaml: Path):
    """
    Patch copied args.yaml so resumed Ultralytics training uses the current Kaggle working paths.
    This matters because /kaggle/input is read-only and each Kaggle session recreates /kaggle/working.
    """
    if not args_yaml.exists():
        print(f"args.yaml not found, skip patch: {args_yaml}")
        return

    with open(args_yaml, "r") as f:
        args = yaml.safe_load(f) or {}

    # Critical current-session paths.
    args["data"]    = str(YAML_PATH)
    args["project"] = str(PROJECT_DIR)
    args["name"]    = RUN_NAME
    args["save_dir"] = str(RUN_DIR)

    # Keep total target epochs configurable from S0.
    args["epochs"]  = EPOCHS

    # Keep hardware settings configurable from S0.
    args["batch"]   = BATCH
    args["workers"] = WORKERS
    args["device"]  = device_str

    with open(args_yaml, "w") as f:
        yaml.safe_dump(args, f, sort_keys=False)

    print(f"Patched args.yaml: {args_yaml}")
    print(f"  data    : {args.get('data')}")
    print(f"  project : {args.get('project')}")
    print(f"  name    : {args.get('name')}")
    print(f"  epochs  : {args.get('epochs')}")
    print(f"  device  : {args.get('device')}")

if RESUME_TRAINING:
    print("\n[resume] Preparing writable checkpoint directory...")

    assert RESUME_RUN_INPUT.exists(), (
        f"Resume run folder not found:\n  {RESUME_RUN_INPUT}\n"
        "Check that the Kaggle dataset is attached and the S0 path is correct."
    )
    assert RESUME_LAST_PT.exists(), (
        f"Resume last.pt not found:\n  {RESUME_LAST_PT}\n"
        "Use weights/last.pt for true resume, not best.pt."
    )

    working_last_pt = RUN_DIR / "weights" / "last.pt"
    working_args_yaml = RUN_DIR / "args.yaml"

    # Do not overwrite a more advanced working checkpoint if this cell is rerun in the same live session.
    if working_last_pt.exists():
        print(f"[resume] Existing working checkpoint found, not overwriting:")
        print(f"         {working_last_pt}")
    else:
        if RUN_DIR.exists():
            print(f"[resume] Existing RUN_DIR has no last.pt; merging input run into it:")
            print(f"         {RUN_DIR}")
        else:
            print(f"[resume] Copying input run folder:")
            print(f"         from: {RESUME_RUN_INPUT}")
            print(f"         to  : {RUN_DIR}")

        shutil.copytree(RESUME_RUN_INPUT, RUN_DIR, dirs_exist_ok=True)

    working_last_pt = RUN_DIR / "weights" / "last.pt"
    working_best_pt = RUN_DIR / "weights" / "best.pt"
    working_args_yaml = RUN_DIR / "args.yaml"

    print("\n[resume] Verification:")
    print(f"  working last.pt : {'OK' if working_last_pt.exists() else 'MISSING'} — {working_last_pt}")
    print(f"  working best.pt : {'OK' if working_best_pt.exists() else 'MISSING'} — {working_best_pt}")
    print(f"  args.yaml       : {'OK' if working_args_yaml.exists() else 'MISSING'} — {working_args_yaml}")

    if working_args_yaml.exists():
        patch_args_yaml(working_args_yaml)

    if working_last_pt.exists() and working_args_yaml.exists():
        print("\n[resume] Starting true Ultralytics resume from last.pt...")
        model = YOLO(str(working_last_pt))
        results = model.train(resume=True)
    elif working_last_pt.exists():
        print("\n[resume] WARNING: args.yaml missing.")
        print("         Falling back to warm-start from last.pt with fresh optimizer state.")
        print("         This is NOT a true optimizer/LR resume.")
        model = YOLO(str(working_last_pt))
        results = model.train(
            data          = str(YAML_PATH),
            epochs        = EPOCHS,
            imgsz         = IMGSZ,
            batch         = BATCH,
            workers       = WORKERS,
            lr0           = LR0,
            lrf           = LRF,
            device        = device_str,
            project       = str(PROJECT_DIR),
            name          = RUN_NAME + "_warmstart",
            hsv_h         = AUGMENT_HSV_H,
            hsv_s         = AUGMENT_HSV_S,
            hsv_v         = AUGMENT_HSV_V,
            flipud        = AUGMENT_FLIPUD,
            degrees       = AUGMENT_DEGREES,
            translate     = AUGMENT_TRANSLATE,
            scale         = AUGMENT_SCALE,
            patience      = 50,
            warmup_epochs = 3.0,
            mosaic        = 1.0,
            weight_decay  = 0.0005,
            verbose       = True,
            seed          = SEED,
        )
    else:
        raise FileNotFoundError(f"Could not prepare working last.pt: {working_last_pt}")

else:
    print("\n[fresh] Starting fresh finetune from SEG_MODEL_INIT...")
    model = YOLO(SEG_MODEL_INIT)
    results = model.train(
        data          = str(YAML_PATH),
        epochs        = EPOCHS,
        imgsz         = IMGSZ,
        batch         = BATCH,
        workers       = WORKERS,
        lr0           = LR0,
        lrf           = LRF,
        device        = device_str,
        project       = str(PROJECT_DIR),
        name          = RUN_NAME,
        # Augmentation (EDA-derived — same as detection baseline)
        hsv_h         = AUGMENT_HSV_H,
        hsv_s         = AUGMENT_HSV_S,
        hsv_v         = AUGMENT_HSV_V,
        flipud        = AUGMENT_FLIPUD,
        degrees       = AUGMENT_DEGREES,
        translate     = AUGMENT_TRANSLATE,
        scale         = AUGMENT_SCALE,
        # Training schedule
        patience      = 50,
        warmup_epochs = 3.0,
        mosaic        = 1.0,
        weight_decay  = 0.0005,
        verbose       = True,
        seed          = SEED,
    )

print(f"\nDone. Save dir  : {results.save_dir}")
print(f"Best model: {results.save_dir}/weights/best.pt")
print(f"Last model: {results.save_dir}/weights/last.pt")
if WANDB_ENABLED and wandb.run:
    print(f"wandb URL : {wandb.run.get_url()}")
# Out:
# ======================================================================
# Training mode
# ======================================================================
#   Resume training : True
#   Device          : 0,1
#   YAML            : /kaggle/working/fasdd_cv_seg.yaml
#   Run name        : yolo11m_seg_finetune_imgsz1024_20260613-2
#   Run dir         : /kaggle/working/fasdd_cv/yolo11m_seg_finetune_imgsz1024_20260613-2
# ======================================================================
#
# [resume] Preparing writable checkpoint directory...
# [resume] Existing RUN_DIR has no last.pt; merging input run into it:
#          /kaggle/working/fasdd_cv/yolo11m_seg_finetune_imgsz1024_20260613-2
#
# [resume] Verification:
#   working last.pt : OK — /kaggle/working/fasdd_cv/yolo11m_seg_finetune_imgsz1024_20260613-2/weights/last.pt
#   working best.pt : OK — /kaggle/working/fasdd_cv/yolo11m_seg_finetune_imgsz1024_20260613-2/weights/best.pt
#   args.yaml       : OK — /kaggle/working/fasdd_cv/yolo11m_seg_finetune_imgsz1024_20260613-2/args.yaml
# Patched args.yaml: /kaggle/working/fasdd_cv/yolo11m_seg_finetune_imgsz1024_20260613-2/args.yaml
#   data    : /kaggle/working/fasdd_cv_seg.yaml
#   project : /kaggle/working/fasdd_cv
#   name    : yolo11m_seg_finetune_imgsz1024_20260613-2
#   epochs  : 100
#   device  : 0,1
#
# [resume] Starting true Ultralytics resume from last.pt...
# Ultralytics 8.4.67 🚀 Python-3.12.13 torch-2.10.0+cu128 CUDA:0 (Tesla T4, 14913MiB)
#                                                        CUDA:1 (Tesla T4, 14913MiB)
# engine/trainer: agnostic_nms=False, amp=True, angle=1.0, augment=False, auto_augment=randaugment, batch=16, bgr=0.0, box=7.5, cache=False, cfg=None, classes=None, close_mosaic=10, cls=0.5, cls_pw=0.0, compile=False, conf=None, copy_paste=0.0, copy_paste_mode=flip, cos_lr=False, cutmix=0.0, data=/kaggle/working/fasdd_cv_seg.yaml, degrees=0.0, deterministic=True, device=0,1, dfl=1.5, dnn=False, dropout=0.0, dynamic=False, embed=None, end2end=None, epochs=100, erasing=0.4, exist_ok=False, fliplr=0.5, flipud=0.0, format=torchscript, fraction=1.0, freeze=None, half=False, hsv_h=0.015, hsv_s=0.7, hsv_v=0.4, imgsz=1024, int8=False, iou=0.7, keras=False, kobj=1.0, line_width=None, lr0=0.01, lrf=0.01, mask_ratio=4, max_det=300, mixup=0.0, mode=train, model=/kaggle/working/fasdd_cv/yolo11m_seg_finetune_imgsz1024_20260613-2/weights/last.pt, momentum=0.937, mosaic=1.0, multi_scale=0.0, name=yolo11m_seg_finetune_imgsz1024_20260613-2, nbs=64, nms=False, opset=None, optimize=False, optimizer=auto, overlap_mask=True, patience=50, perspective=0.0, plots=True, pose=12.0, pretrained=True, profile=False, project=/kaggle/working/fasdd_cv, rect=False, resume=/kaggle/working/fasdd_cv/yolo11m_seg_finetune_imgsz1024_20260613-2/weights/last.pt, retina_masks=False, rle=1.0, save=True, save_conf=False, save_crop=False, save_dir=/kaggle/working/fasdd_cv/yolo11m_seg_finetune_imgsz1024_20260613-2, save_frames=False, save_json=False, save_period=-1, save_txt=False, scale=0.5, seed=42, shear=0.0, show=False, show_boxes=True, show_conf=True, show_labels=True, simplify=True, single_cls=False, source=None, split=val, stream_buffer=False, task=segment, time=None, tracker=botsort.yaml, translate=0.2, val=True, verbose=True, vid_stride=1, visualize=False, warmup_bias_lr=0.0, warmup_epochs=3.0, warmup_momentum=0.8, weight_decay=0.0005, workers=4, workspace=None
# Downloading https://ultralytics.com/assets/Arial.ttf to '/root/.config/Ultralytics/Arial.ttf': 100% ━━━━━━━━━━━━ 755.1KB 16.9MB/s 0.0s
# DDP: debug command /usr/bin/python3 -m torch.distributed.run --nproc_per_node 2 --master_port 37359 /root/.config/Ultralytics/DDP/_temp_uqq1z8rd134991495307936.py
# Ultralytics 8.4.67 🚀 Python-3.12.13 torch-2.10.0+cu128 CUDA:0 (Tesla T4, 14913MiB)
#                                                        CUDA:1 (Tesla T4, 14913MiB)
# Transferred 711/711 items from pretrained weights
# Freezing layer 'model.23.dfl.conv.weight'
# AMP: running Automatic Mixed Precision (AMP) checks...
# Downloading https://github.com/ultralytics/assets/releases/download/v8.4.0/yolo26n.pt to 'yolo26n.pt': 100% ━━━━━━━━━━━━ 5.3MB 71.5MB/s 0.1s
# AMP: checks passed ✅
# train: Fast image access ✅ (ping: 3.4±0.6 ms, read: 18.0±8.0 MB/s, size: 131.2 KB)
# train: Scanning /kaggle/working/labels... 16352 images, 3197 backgrounds, 0 corrupt: 40% ━━━━╸─────── 19537/47660 273.5it/s 1:11<1:43
# /usr/local/lib/python3.12/dist-packages/PIL/TiffImagePlugin.py:950: UserWarning: Corrupt EXIF data.  Expecting to read 4 bytes but only got 0.
#   warnings.warn(str(msg))
# train: Scanning /kaggle/working/labels... 28060 images, 19613 backgrounds, 0 corrupt: 100% ━━━━━━━━━━━━ 47660/47660 280.5it/s 2:500.0ss
# train: /kaggle/working/images/bothFireAndSmoke_CV000673.jpg: 1 duplicate labels removed
# train: /kaggle/working/images/bothFireAndSmoke_CV000680.jpg: 1 duplicate labels removed
# train: /kaggle/working/images/bothFireAndSmoke_CV000773.jpg: 1 duplicate labels removed
# train: /kaggle/working/images/bothFireAndSmoke_CV000778.jpg: 1 duplicate labels removed
# train: /kaggle/working/images/bothFireAndSmoke_CV000812.jpg: 1 duplicate labels removed
# train: /kaggle/working/images/bothFireAndSmoke_CV000859.jpg: 1 duplicate labels removed
# train: /kaggle/working/images/bothFireAndSmoke_CV000860.jpg: 1 duplicate labels removed
# train: /kaggle/working/images/bothFireAndSmoke_CV000888.jpg: 1 duplicate labels removed
# train: /kaggle/working/images/bothFireAndSmoke_CV000889.jpg: 1 duplicate labels removed
# train: /kaggle/working/images/bothFireAndSmoke_CV000926.jpg: 1 duplicate labels removed
# train: /kaggle/working/images/bothFireAndSmoke_CV000928.jpg: 1 duplicate labels removed
# train: /kaggle/working/images/bothFireAndSmoke_CV000993.jpg: 1 duplicate labels removed
# train: /kaggle/working/images/bothFireAndSmoke_CV001000.jpg: 1 duplicate labels removed
# train: /kaggle/working/images/bothFireAndSmoke_CV001006.jpg: 1 duplicate labels removed
# train: /kaggle/working/images/bothFireAndSmoke_CV001099.jpg: 1 duplicate labels removed
# train: /kaggle/working/images/bothFireAndSmoke_CV001167.jpg: 1 duplicate labels removed
# train: /kaggle/working/images/bothFireAndSmoke_CV001190.jpg: 1 duplicate labels removed
# train: /kaggle/working/images/bothFireAndSmoke_CV001217.jpg: 1 duplicate labels removed
# train: /kaggle/working/images/bothFireAndSmoke_CV001244.jpg: 1 duplicate labels removed
# train: /kaggle/working/images/bothFireAndSmoke_CV001306.jpg: 1 duplicate labels removed
# train: /kaggle/working/images/bothFireAndSmoke_CV001364.jpg: 1 duplicate labels removed
# train: /kaggle/working/images/bothFireAndSmoke_CV001382.jpg: 1 duplicate labels removed
# train: /kaggle/working/images/bothFireAndSmoke_CV001383.jpg: 1 duplicate labels removed
# train: /kaggle/working/images/bothFireAndSmoke_CV001412.jpg: 1 duplicate labels removed
# train: /kaggle/working/images/bothFireAndSmoke_CV001421.jpg: 1 duplicate labels removed
# train: /kaggle/working/images/bothFireAndSmoke_CV001443.jpg: 1 duplicate labels removed
# train: /kaggle/working/images/bothFireAndSmoke_CV001454.jpg: 1 duplicate labels removed
# train: /kaggle/working/images/bothFireAndSmoke_CV001501.jpg: 1 duplicate labels removed
# train: /kaggle/working/images/bothFireAndSmoke_CV001509.jpg: 1 duplicate labels removed
# train: /kaggle/working/images/bothFireAndSmoke_CV001510.jpg: 1 duplicate labels removed
# train: /kaggle/working/images/bothFireAndSmoke_CV001544.jpg: 1 duplicate labels removed
# train: /kaggle/working/images/bothFireAndSmoke_CV001553.jpg: 1 duplicate labels removed
# train: /kaggle/working/images/bothFireAndSmoke_CV001690.jpg: 1 duplicate labels removed
# train: /kaggle/working/images/bothFireAndSmoke_CV001886.jpg: 1 duplicate labels removed
# train: /kaggle/working/images/bothFireAndSmoke_CV001936.jpg: 1 duplicate labels removed
# train: /kaggle/working/images/bothFireAndSmoke_CV001944.jpg: 1 duplicate labels removed
# train: /kaggle/working/images/bothFireAndSmoke_CV002041.jpg: 1 duplicate labels removed
# train: /kaggle/working/images/bothFireAndSmoke_CV002077.jpg: 1 duplicate labels removed
# train: /kaggle/working/images/bothFireAndSmoke_CV002105.jpg: 1 duplicate labels removed
# train: /kaggle/working/images/bothFireAndSmoke_CV002113.jpg: 1 duplicate labels removed
# train: /kaggle/working/images/bothFireAndSmoke_CV002128.jpg: 1 duplicate labels removed
# train: /kaggle/working/images/bothFireAndSmoke_CV002192.jpg: 1 duplicate labels removed
# train: /kaggle/working/images/bothFireAndSmoke_CV002231.jpg: 1 duplicate labels removed
# train: /kaggle/working/images/bothFireAndSmoke_CV002232.jpg: 1 duplicate labels removed
# train: /kaggle/working/images/bothFireAndSmoke_CV002287.jpg: 1 duplicate labels removed
# train: /kaggle/working/images/bothFireAndSmoke_CV002303.jpg: 1 duplicate labels removed
# train: /kaggle/working/images/bothFireAndSmoke_CV002506.jpg: 1 duplicate labels removed
# train: /kaggle/working/images/bothFireAndSmoke_CV002511.jpg: 1 duplicate labels removed
# train: /kaggle/working/images/bothFireAndSmoke_CV002623.jpg: 1 duplicate labels removed
# train: /kaggle/working/images/bothFireAndSmoke_CV002857.jpg: 1 duplicate labels removed
# train: /kaggle/working/images/bothFireAndSmoke_CV002923.jpg: 1 duplicate labels removed
# train: /kaggle/working/images/bothFireAndSmoke_CV002939.jpg: 1 duplicate labels removed
# train: /kaggle/working/images/bothFireAndSmoke_CV002946.jpg: 1 duplicate labels removed
# train: /kaggle/working/images/bothFireAndSmoke_CV002976.jpg: 1 duplicate labels removed
# train: /kaggle/working/images/bothFireAndSmoke_CV003047.jpg: 1 duplicate labels removed
# train: /kaggle/working/images/bothFireAndSmoke_CV003059.jpg: 1 duplicate labels removed
# train: /kaggle/working/images/bothFireAndSmoke_CV003071.jpg: 1 duplicate labels removed
# train: /kaggle/working/images/bothFireAndSmoke_CV003102.jpg: 1 duplicate labels removed
# train: /kaggle/working/images/bothFireAndSmoke_CV003136.jpg: 1 duplicate labels removed
# train: /kaggle/working/images/bothFireAndSmoke_CV003162.jpg: 1 duplicate labels removed
# train: /kaggle/working/images/bothFireAndSmoke_CV003191.jpg: 1 duplicate labels removed
# train: /kaggle/working/images/bothFireAndSmoke_CV003201.jpg: 1 duplicate labels removed
# train: /kaggle/working/images/bothFireAndSmoke_CV003206.jpg: 1 duplicate labels removed
# train: /kaggle/working/images/bothFireAndSmoke_CV003223.jpg: 1 duplicate labels removed
# train: /kaggle/working/images/bothFireAndSmoke_CV003237.jpg: 1 duplicate labels removed
# train: /kaggle/working/images/bothFireAndSmoke_CV003243.jpg: 1 duplicate labels removed
# train: /kaggle/working/images/bothFireAndSmoke_CV003248.jpg: 1 duplicate labels removed
# train: /kaggle/working/images/bothFireAndSmoke_CV003257.jpg: 1 duplicate labels removed
# train: /kaggle/working/images/bothFireAndSmoke_CV003263.jpg: 1 duplicate labels removed
# train: /kaggle/working/images/bothFireAndSmoke_CV003264.jpg: 1 duplicate labels removed
# train: /kaggle/working/images/bothFireAndSmoke_CV003267.jpg: 1 duplicate labels removed
# train: /kaggle/working/images/bothFireAndSmoke_CV003298.jpg: 1 duplicate labels removed
# train: /kaggle/working/images/bothFireAndSmoke_CV003300.jpg: 1 duplicate labels removed
# train: /kaggle/working/images/bothFireAndSmoke_CV003311.jpg: 1 duplicate labels removed
# train: /kaggle/working/images/bothFireAndSmoke_CV003333.jpg: 1 duplicate labels removed
# train: /kaggle/working/images/bothFireAndSmoke_CV003375.jpg: 1 duplicate labels removed
# train: /kaggle/working/images/bothFireAndSmoke_CV003402.jpg: 1 duplicate labels removed
# train: /kaggle/working/images/bothFireAndSmoke_CV003415.jpg: 1 duplicate labels removed
# train: /kaggle/working/images/bothFireAndSmoke_CV003419.jpg: 2 duplicate labels removed
# train: /kaggle/working/images/bothFireAndSmoke_CV003427.jpg: 1 duplicate labels removed
# train: /kaggle/working/images/bothFireAndSmoke_CV003443.jpg: 1 duplicate labels removed
# train: /kaggle/working/images/bothFireAndSmoke_CV003454.jpg: 1 duplicate labels removed
# train: /kaggle/working/images/bothFireAndSmoke_CV003464.jpg: 1 duplicate labels removed
# train: /kaggle/working/images/bothFireAndSmoke_CV003503.jpg: 1 duplicate labels removed
# train: /kaggle/working/images/bothFireAndSmoke_CV003545.jpg: 1 duplicate labels removed
# train: /kaggle/working/images/bothFireAndSmoke_CV003549.jpg: 1 duplicate labels removed
# train: /kaggle/working/images/bothFireAndSmoke_CV003594.jpg: 1 duplicate labels removed
# train: /kaggle/working/images/bothFireAndSmoke_CV003608.jpg: 1 duplicate labels removed
# train: /kaggle/working/images/bothFireAndSmoke_CV003663.jpg: 1 duplicate labels removed
# train: /kaggle/working/images/bothFireAndSmoke_CV003671.jpg: 2 duplicate labels removed
# train: /kaggle/working/images/bothFireAndSmoke_CV003739.jpg: 1 duplicate labels removed
# train: /kaggle/working/images/bothFireAndSmoke_CV003758.jpg: 1 duplicate labels removed
# train: /kaggle/working/images/bothFireAndSmoke_CV003817.jpg: 1 duplicate labels removed
# train: /kaggle/working/images/bothFireAndSmoke_CV003874.jpg: 1 duplicate labels removed
# train: /kaggle/working/images/bothFireAndSmoke_CV003909.jpg: 1 duplicate labels removed
# train: /kaggle/working/images/bothFireAndSmoke_CV003951.jpg: 1 duplicate labels removed
# train: /kaggle/working/images/bothFireAndSmoke_CV003961.jpg: 1 duplicate labels removed
# train: /kaggle/working/images/bothFireAndSmoke_CV004040.jpg: 1 duplicate labels removed
# train: /kaggle/working/images/bothFireAndSmoke_CV004092.jpg: 1 duplicate labels removed
# train: /kaggle/working/images/bothFireAndSmoke_CV004110.jpg: 1 duplicate labels removed
# train: /kaggle/working/images/bothFireAndSmoke_CV004178.jpg: 1 duplicate labels removed
# train: /kaggle/working/images/bothFireAndSmoke_CV004232.jpg: 1 duplicate labels removed
# train: /kaggle/working/images/bothFireAndSmoke_CV004240.jpg: 1 duplicate labels removed
# train: /kaggle/working/images/bothFireAndSmoke_CV004274.jpg: 2 duplicate labels removed
# train: /kaggle/working/images/bothFireAndSmoke_CV004284.jpg: 1 duplicate labels removed
# train: /kaggle/working/images/bothFireAndSmoke_CV004296.jpg: 1 duplicate labels removed
# train: /kaggle/working/images/bothFireAndSmoke_CV004301.jpg: 1 duplicate labels removed
# train: /kaggle/working/images/bothFireAndSmoke_CV004326.jpg: 1 duplicate labels removed
# train: /kaggle/working/images/bothFireAndSmoke_CV004344.jpg: 1 duplicate labels removed
# train: /kaggle/working/images/bothFireAndSmoke_CV004356.jpg: 1 duplicate labels removed
# train: /kaggle/working/images/bothFireAndSmoke_CV004367.jpg: 1 duplicate labels removed
# train: /kaggle/working/images/bothFireAndSmoke_CV004374.jpg: 1 duplicate labels removed
# train: /kaggle/working/images/bothFireAndSmoke_CV004413.jpg: 1 duplicate labels removed
# train: /kaggle/working/images/bothFireAndSmoke_CV004437.jpg: 1 duplicate labels removed
# train: /kaggle/working/images/bothFireAndSmoke_CV004444.jpg: 1 duplicate labels removed
# train: /kaggle/working/images/bothFireAndSmoke_CV004451.jpg: 2 duplicate labels removed
# train: /kaggle/working/images/bothFireAndSmoke_CV004485.jpg: 1 duplicate labels removed
# train: /kaggle/working/images/bothFireAndSmoke_CV004513.jpg: 1 duplicate labels removed
# train: /kaggle/working/images/bothFireAndSmoke_CV004523.jpg: 1 duplicate labels removed
# train: /kaggle/working/images/bothFireAndSmoke_CV004568.jpg: 1 duplicate labels removed
# train: /kaggle/working/images/bothFireAndSmoke_CV004572.jpg: 1 duplicate labels removed
# train: /kaggle/working/images/bothFireAndSmoke_CV004600.jpg: 1 duplicate labels removed
# train: /kaggle/working/images/bothFireAndSmoke_CV004612.jpg: 1 duplicate labels removed
# train: /kaggle/working/images/bothFireAndSmoke_CV004622.jpg: 1 duplicate labels removed
# train: /kaggle/working/images/bothFireAndSmoke_CV004650.jpg: 2 duplicate labels removed
# train: /kaggle/working/images/bothFireAndSmoke_CV004673.jpg: 1 duplicate labels removed
# train: /kaggle/working/images/bothFireAndSmoke_CV004700.jpg: 1 duplicate labels removed
# train: /kaggle/working/images/bothFireAndSmoke_CV004703.jpg: 1 duplicate labels removed
# train: /kaggle/working/images/bothFireAndSmoke_CV004712.jpg: 1 duplicate labels removed
# train: /kaggle/working/images/bothFireAndSmoke_CV004730.jpg: 1 duplicate labels removed
# train: /kaggle/working/images/bothFireAndSmoke_CV004735.jpg: 1 duplicate labels removed
# train: /kaggle/working/images/bothFireAndSmoke_CV004756.jpg: 1 duplicate labels removed
# train: /kaggle/working/images/bothFireAndSmoke_CV004779.jpg: 1 duplicate labels removed
# train: /kaggle/working/images/bothFireAndSmoke_CV004820.jpg: 1 duplicate labels removed
# train: /kaggle/working/images/bothFireAndSmoke_CV004829.jpg: 1 duplicate labels removed
# train: /kaggle/working/images/bothFireAndSmoke_CV004843.jpg: 1 duplicate labels removed
# train: /kaggle/working/images/bothFireAndSmoke_CV004849.jpg: 1 duplicate labels removed
# train: /kaggle/working/images/bothFireAndSmoke_CV004856.jpg: 1 duplicate labels removed
# train: /kaggle/working/images/bothFireAndSmoke_CV004863.jpg: 1 duplicate labels removed
# train: /kaggle/working/images/bothFireAndSmoke_CV004887.jpg: 1 duplicate labels removed
# train: /kaggle/working/images/bothFireAndSmoke_CV004894.jpg: 1 duplicate labels removed
# train: /kaggle/working/images/bothFireAndSmoke_CV004991.jpg: 1 duplicate labels removed
# train: /kaggle/working/images/bothFireAndSmoke_CV004997.jpg: 1 duplicate labels removed
# train: /kaggle/working/images/bothFireAndSmoke_CV005043.jpg: 2 duplicate labels removed
# train: /kaggle/working/images/bothFireAndSmoke_CV005047.jpg: 1 duplicate labels removed
# train: /kaggle/working/images/bothFireAndSmoke_CV005077.jpg: 1 duplicate labels removed
# train: /kaggle/working/images/bothFireAndSmoke_CV005138.jpg: 1 duplicate labels removed
# train: /kaggle/working/images/bothFireAndSmoke_CV005144.jpg: 1 duplicate labels removed
# train: /kaggle/working/images/bothFireAndSmoke_CV005161.jpg: 1 duplicate labels removed
# train: /kaggle/working/images/bothFireAndSmoke_CV005165.jpg: 1 duplicate labels removed
# train: /kaggle/working/images/bothFireAndSmoke_CV005169.jpg: 1 duplicate labels removed
# train: /kaggle/working/images/bothFireAndSmoke_CV005199.jpg: 1 duplicate labels removed
# train: /kaggle/working/images/bothFireAndSmoke_CV005222.jpg: 1 duplicate labels removed
# train: /kaggle/working/images/bothFireAndSmoke_CV005229.jpg: 1 duplicate labels removed
# train: /kaggle/working/images/bothFireAndSmoke_CV005268.jpg: 1 duplicate labels removed
# train: /kaggle/working/images/bothFireAndSmoke_CV005291.jpg: 1 duplicate labels removed
# train: /kaggle/working/images/bothFireAndSmoke_CV005321.jpg: 1 duplicate labels removed
# train: /kaggle/working/images/bothFireAndSmoke_CV005346.jpg: 1 duplicate labels removed
# train: /kaggle/working/images/bothFireAndSmoke_CV005363.jpg: 1 duplicate labels removed
# train: /kaggle/working/images/bothFireAndSmoke_CV005364.jpg: 1 duplicate labels removed
# train: /kaggle/working/images/bothFireAndSmoke_CV005365.jpg: 1 duplicate labels removed
# train: /kaggle/working/images/bothFireAndSmoke_CV005423.jpg: 1 duplicate labels removed
# train: /kaggle/working/images/bothFireAndSmoke_CV005445.jpg: 1 duplicate labels removed
# train: /kaggle/working/images/bothFireAndSmoke_CV005614.jpg: 1 duplicate labels removed
# train: /kaggle/working/images/bothFireAndSmoke_CV005750.jpg: 1 duplicate labels removed
# train: /kaggle/working/images/bothFireAndSmoke_CV005799.jpg: 1 duplicate labels removed
# train: /kaggle/working/images/bothFireAndSmoke_CV005976.jpg: 2 duplicate labels removed
# train: /kaggle/working/images/bothFireAndSmoke_CV006010.jpg: 1 duplicate labels removed
# train: /kaggle/working/images/bothFireAndSmoke_CV006220.jpg: 1 duplicate labels removed
# train: /kaggle/working/images/bothFireAndSmoke_CV006360.jpg: 1 duplicate labels removed
# train: /kaggle/working/images/bothFireAndSmoke_CV006389.jpg: 1 duplicate labels removed
# train: /kaggle/working/images/bothFireAndSmoke_CV006446.jpg: 1 duplicate labels removed
# train: /kaggle/working/images/bothFireAndSmoke_CV006520.jpg: 1 duplicate labels removed
# train: /kaggle/working/images/bothFireAndSmoke_CV006531.jpg: 1 duplicate labels removed
# train: /kaggle/working/images/bothFireAndSmoke_CV006548.jpg: 1 duplicate labels removed
# train: /kaggle/working/images/bothFireAndSmoke_CV006558.jpg: 1 duplicate labels removed
# train: /kaggle/working/images/bothFireAndSmoke_CV006598.jpg: 1 duplicate labels removed
# train: /kaggle/working/images/bothFireAndSmoke_CV006626.jpg: 1 duplicate labels removed
# train: /kaggle/working/images/bothFireAndSmoke_CV006628.jpg: 2 duplicate labels removed
# train: /kaggle/working/images/bothFireAndSmoke_CV006637.jpg: 1 duplicate labels removed
# train: /kaggle/working/images/bothFireAndSmoke_CV006712.jpg: 1 duplicate labels removed
# train: /kaggle/working/images/bothFireAndSmoke_CV006785.jpg: 1 duplicate labels removed
# train: /kaggle/working/images/bothFireAndSmoke_CV006815.jpg: 1 duplicate labels removed
# train: /kaggle/working/images/bothFireAndSmoke_CV006823.jpg: 1 duplicate labels removed
# train: /kaggle/working/images/bothFireAndSmoke_CV006885.jpg: 1 duplicate labels removed
# train: /kaggle/working/images/bothFireAndSmoke_CV006911.jpg: 1 duplicate labels removed
# train: /kaggle/working/images/bothFireAndSmoke_CV006952.jpg: 1 duplicate labels removed
# train: /kaggle/working/images/bothFireAndSmoke_CV006958.jpg: 1 duplicate labels removed
# train: /kaggle/working/images/bothFireAndSmoke_CV006966.jpg: 1 duplicate labels removed
# train: /kaggle/working/images/bothFireAndSmoke_CV007032.jpg: 1 duplicate labels removed
# train: /kaggle/working/images/bothFireAndSmoke_CV007071.jpg: 1 duplicate labels removed
# train: /kaggle/working/images/bothFireAndSmoke_CV007074.jpg: 1 duplicate labels removed
# train: /kaggle/working/images/bothFireAndSmoke_CV007085.jpg: 1 duplicate labels removed
# train: /kaggle/working/images/bothFireAndSmoke_CV007109.jpg: 1 duplicate labels removed
# train: /kaggle/working/images/bothFireAndSmoke_CV007189.jpg: 1 duplicate labels removed
# train: /kaggle/working/images/bothFireAndSmoke_CV007217.jpg: 1 duplicate labels removed
# train: /kaggle/working/images/bothFireAndSmoke_CV007260.jpg: 1 duplicate labels removed
# train: /kaggle/working/images/bothFireAndSmoke_CV007282.jpg: 1 duplicate labels removed
# train: /kaggle/working/images/bothFireAndSmoke_CV007304.jpg: 1 duplicate labels removed
# train: /kaggle/working/images/bothFireAndSmoke_CV007334.jpg: 1 duplicate labels removed
# train: /kaggle/working/images/bothFireAndSmoke_CV007346.jpg: 1 duplicate labels removed
# train: /kaggle/working/images/bothFireAndSmoke_CV007366.jpg: 1 duplicate labels removed
# train: /kaggle/working/images/bothFireAndSmoke_CV007398.jpg: 1 duplicate labels removed
# train: /kaggle/working/images/bothFireAndSmoke_CV007403.jpg: 3 duplicate labels removed
# train: /kaggle/working/images/bothFireAndSmoke_CV007412.jpg: 1 duplicate labels removed
# train: /kaggle/working/images/bothFireAndSmoke_CV007415.jpg: 1 duplicate labels removed
# train: /kaggle/working/images/bothFireAndSmoke_CV007440.jpg: 1 duplicate labels removed
# train: /kaggle/working/images/bothFireAndSmoke_CV007450.jpg: 1 duplicate labels removed
# train: /kaggle/working/images/bothFireAndSmoke_CV007451.jpg: 1 duplicate labels removed
# train: /kaggle/working/images/bothFireAndSmoke_CV007515.jpg: 1 duplicate labels removed
# train: /kaggle/working/images/bothFireAndSmoke_CV007524.jpg: 1 duplicate labels removed
# train: /kaggle/working/images/bothFireAndSmoke_CV007527.jpg: 2 duplicate labels removed
# train: /kaggle/working/images/bothFireAndSmoke_CV007657.jpg: 2 duplicate labels removed
# train: /kaggle/working/images/bothFireAndSmoke_CV007693.jpg: 1 duplicate labels removed
# train: /kaggle/working/images/bothFireAndSmoke_CV007721.jpg: 2 duplicate labels removed
# train: /kaggle/working/images/bothFireAndSmoke_CV007817.jpg: 1 duplicate labels removed
# train: /kaggle/working/images/bothFireAndSmoke_CV007852.jpg: 1 duplicate labels removed
# train: /kaggle/working/images/bothFireAndSmoke_CV007942.jpg: 1 duplicate labels removed
# train: /kaggle/working/images/bothFireAndSmoke_CV007943.jpg: 1 duplicate labels removed
# train: /kaggle/working/images/bothFireAndSmoke_CV007947.jpg: 1 duplicate labels removed
# train: /kaggle/working/images/bothFireAndSmoke_CV007959.jpg: 1 duplicate labels removed
# train: /kaggle/working/images/bothFireAndSmoke_CV007963.jpg: 3 duplicate labels removed
# train: /kaggle/working/images/bothFireAndSmoke_CV008006.jpg: 2 duplicate labels removed
# train: /kaggle/working/images/bothFireAndSmoke_CV008041.jpg: 1 duplicate labels removed
# train: /kaggle/working/images/bothFireAndSmoke_CV008099.jpg: 1 duplicate labels removed
# train: /kaggle/working/images/bothFireAndSmoke_CV008102.jpg: 1 duplicate labels removed
# train: /kaggle/working/images/bothFireAndSmoke_CV008131.jpg: 1 duplicate labels removed
# train: /kaggle/working/images/bothFireAndSmoke_CV008171.jpg: 1 duplicate labels removed
# train: /kaggle/working/images/bothFireAndSmoke_CV008221.jpg: 1 duplicate labels removed
# train: /kaggle/working/images/bothFireAndSmoke_CV008232.jpg: 1 duplicate labels removed
# train: /kaggle/working/images/bothFireAndSmoke_CV008248.jpg: 1 duplicate labels removed
# train: /kaggle/working/images/bothFireAndSmoke_CV008319.jpg: 1 duplicate labels removed
# train: /kaggle/working/images/bothFireAndSmoke_CV008351.jpg: 1 duplicate labels removed
# train: /kaggle/working/images/bothFireAndSmoke_CV008374.jpg: 1 duplicate labels removed
# train: /kaggle/working/images/bothFireAndSmoke_CV008398.jpg: 2 duplicate labels removed
# train: /kaggle/working/images/bothFireAndSmoke_CV008405.jpg: 2 duplicate labels removed
# train: /kaggle/working/images/bothFireAndSmoke_CV008477.jpg: 1 duplicate labels removed
# train: /kaggle/working/images/bothFireAndSmoke_CV008523.jpg: 1 duplicate labels removed
# train: /kaggle/working/images/bothFireAndSmoke_CV008527.jpg: 1 duplicate labels removed
# train: /kaggle/working/images/bothFireAndSmoke_CV008575.jpg: 1 duplicate labels removed
# train: /kaggle/working/images/bothFireAndSmoke_CV008598.jpg: 1 duplicate labels removed
# train: /kaggle/working/images/bothFireAndSmoke_CV008667.jpg: 1 duplicate labels removed
# train: /kaggle/working/images/bothFireAndSmoke_CV008890.jpg: 1 duplicate labels removed
# train: /kaggle/working/images/bothFireAndSmoke_CV008920.jpg: 1 duplicate labels removed
# train: /kaggle/working/images/bothFireAndSmoke_CV008992.jpg: 1 duplicate labels removed
# train: /kaggle/working/images/bothFireAndSmoke_CV009005.jpg: 1 duplicate labels removed
# train: /kaggle/working/images/bothFireAndSmoke_CV009022.jpg: 1 duplicate labels removed
# train: /kaggle/working/images/bothFireAndSmoke_CV009056.jpg: 1 duplicate labels removed
# train: /kaggle/working/images/bothFireAndSmoke_CV009097.jpg: 2 duplicate labels removed
# train: /kaggle/working/images/bothFireAndSmoke_CV009104.jpg: 1 duplicate labels removed
# train: /kaggle/working/images/bothFireAndSmoke_CV009127.jpg: 1 duplicate labels removed
# train: /kaggle/working/images/bothFireAndSmoke_CV009146.jpg: 1 duplicate labels removed
# train: /kaggle/working/images/bothFireAndSmoke_CV009150.jpg: 1 duplicate labels removed
# train: /kaggle/working/images/bothFireAndSmoke_CV009156.jpg: 1 duplicate labels removed
# train: /kaggle/working/images/bothFireAndSmoke_CV009192.jpg: 2 duplicate labels removed
# train: /kaggle/working/images/bothFireAndSmoke_CV009196.jpg: 1 duplicate labels removed
# train: /kaggle/working/images/bothFireAndSmoke_CV009219.jpg: 1 duplicate labels removed
# train: /kaggle/working/images/bothFireAndSmoke_CV009231.jpg: 1 duplicate labels removed
# train: /kaggle/working/images/bothFireAndSmoke_CV009250.jpg: 2 duplicate labels removed
# train: /kaggle/working/images/bothFireAndSmoke_CV009285.jpg: 2 duplicate labels removed
# train: /kaggle/working/images/bothFireAndSmoke_CV009293.jpg: 1 duplicate labels removed
# train: /kaggle/working/images/bothFireAndSmoke_CV009295.jpg: 1 duplicate labels removed
# train: /kaggle/working/images/bothFireAndSmoke_CV009321.jpg: 1 duplicate labels removed
# train: /kaggle/working/images/bothFireAndSmoke_CV009324.jpg: 1 duplicate labels removed
# train: /kaggle/working/images/bothFireAndSmoke_CV009383.jpg: 1 duplicate labels removed
# train: /kaggle/working/images/bothFireAndSmoke_CV009410.jpg: 1 duplicate labels removed
# train: /kaggle/working/images/bothFireAndSmoke_CV009430.jpg: 1 duplicate labels removed
# train: /kaggle/working/images/bothFireAndSmoke_CV009431.jpg: 1 duplicate labels removed
# train: /kaggle/working/images/bothFireAndSmoke_CV009436.jpg: 1 duplicate labels removed
# train: /kaggle/working/images/bothFireAndSmoke_CV009451.jpg: 1 duplicate labels removed
# train: /kaggle/working/images/bothFireAndSmoke_CV009476.jpg: 1 duplicate labels removed
# train: /kaggle/working/images/bothFireAndSmoke_CV009483.jpg: 1 duplicate labels removed
# train: /kaggle/working/images/bothFireAndSmoke_CV009511.jpg: 1 duplicate labels removed
# train: /kaggle/working/images/bothFireAndSmoke_CV009517.jpg: 1 duplicate labels removed
# train: /kaggle/working/images/bothFireAndSmoke_CV009545.jpg: 1 duplicate labels removed
# train: /kaggle/working/images/bothFireAndSmoke_CV009561.jpg: 2 duplicate labels removed
# train: /kaggle/working/images/bothFireAndSmoke_CV009576.jpg: 1 duplicate labels removed
# train: /kaggle/working/images/bothFireAndSmoke_CV009584.jpg: 4 duplicate labels removed
# train: /kaggle/working/images/bothFireAndSmoke_CV009589.jpg: 1 duplicate labels removed
# train: /kaggle/working/images/bothFireAndSmoke_CV009605.jpg: 1 duplicate labels removed
# train: /kaggle/working/images/bothFireAndSmoke_CV009623.jpg: 1 duplicate labels removed
# train: /kaggle/working/images/bothFireAndSmoke_CV009635.jpg: 1 duplicate labels removed
# train: /kaggle/working/images/bothFireAndSmoke_CV009661.jpg: 1 duplicate labels removed
# train: /kaggle/working/images/bothFireAndSmoke_CV009719.jpg: 1 duplicate labels removed
# train: /kaggle/working/images/bothFireAndSmoke_CV009740.jpg: 1 duplicate labels removed
# train: /kaggle/working/images/bothFireAndSmoke_CV009760.jpg: 1 duplicate labels removed
# train: /kaggle/working/images/bothFireAndSmoke_CV009761.jpg: 1 duplicate labels removed
# train: /kaggle/working/images/bothFireAndSmoke_CV009777.jpg: 1 duplicate labels removed
# train: /kaggle/working/images/bothFireAndSmoke_CV009790.jpg: 1 duplicate labels removed
# train: /kaggle/working/images/bothFireAndSmoke_CV009797.jpg: 1 duplicate labels removed
# train: /kaggle/working/images/bothFireAndSmoke_CV009817.jpg: 1 duplicate labels removed
# train: /kaggle/working/images/bothFireAndSmoke_CV009861.jpg: 1 duplicate labels removed
# train: /kaggle/working/images/bothFireAndSmoke_CV009887.jpg: 1 duplicate labels removed
# train: /kaggle/working/images/bothFireAndSmoke_CV009892.jpg: 1 duplicate labels removed
# train: /kaggle/working/images/bothFireAndSmoke_CV009900.jpg: 1 duplicate labels removed
# train: /kaggle/working/images/bothFireAndSmoke_CV010062.jpg: 1 duplicate labels removed
# train: /kaggle/working/images/bothFireAndSmoke_CV010063.jpg: 1 duplicate labels removed
# train: /kaggle/working/images/bothFireAndSmoke_CV010072.jpg: 1 duplicate labels removed
# train: /kaggle/working/images/bothFireAndSmoke_CV010099.jpg: 1 duplicate labels removed
# train: /kaggle/working/images/bothFireAndSmoke_CV010101.jpg: 1 duplicate labels removed
# train: /kaggle/working/images/bothFireAndSmoke_CV010392.jpg: 1 duplicate labels removed
# train: /kaggle/working/images/bothFireAndSmoke_CV010398.jpg: 1 duplicate labels removed
# train: /kaggle/working/images/bothFireAndSmoke_CV010439.jpg: 1 duplicate labels removed
# train: /kaggle/working/images/bothFireAndSmoke_CV010448.jpg: 1 duplicate labels removed
# train: /kaggle/working/images/bothFireAndSmoke_CV010494.jpg: 1 duplicate labels removed
# train: /kaggle/working/images/bothFireAndSmoke_CV010528.jpg: 1 duplicate labels removed
# train: /kaggle/working/images/bothFireAndSmoke_CV010530.jpg: 1 duplicate labels removed
# train: /kaggle/working/images/bothFireAndSmoke_CV010540.jpg: 1 duplicate labels removed
# train: /kaggle/working/images/bothFireAndSmoke_CV010543.jpg: 1 duplicate labels removed
# train: /kaggle/working/images/bothFireAndSmoke_CV010566.jpg: 1 duplicate labels removed
# train: /kaggle/working/images/bothFireAndSmoke_CV010577.jpg: 1 duplicate labels removed
# train: /kaggle/working/images/bothFireAndSmoke_CV010595.jpg: 1 duplicate labels removed
# train: /kaggle/working/images/bothFireAndSmoke_CV010626.jpg: 1 duplicate labels removed
# train: /kaggle/working/images/bothFireAndSmoke_CV010645.jpg: 1 duplicate labels removed
# train: /kaggle/working/images/bothFireAndSmoke_CV010655.jpg: 1 duplicate labels removed
# train: /kaggle/working/images/bothFireAndSmoke_CV010705.jpg: 1 duplicate labels removed
# train: /kaggle/working/images/bothFireAndSmoke_CV010722.jpg: 1 duplicate labels removed
# train: /kaggle/working/images/bothFireAndSmoke_CV010727.jpg: 1 duplicate labels removed
# train: /kaggle/working/images/bothFireAndSmoke_CV010731.jpg: 2 duplicate labels removed
# train: /kaggle/working/images/bothFireAndSmoke_CV010772.jpg: 1 duplicate labels removed
# train: /kaggle/working/images/bothFireAndSmoke_CV010783.jpg: 1 duplicate labels removed
# train: /kaggle/working/images/bothFireAndSmoke_CV010808.jpg: 1 duplicate labels removed
# train: /kaggle/working/images/bothFireAndSmoke_CV010830.jpg: 1 duplicate labels removed
# train: /kaggle/working/images/bothFireAndSmoke_CV010844.jpg: 1 duplicate labels removed
# train: /kaggle/working/images/bothFireAndSmoke_CV010880.jpg: 1 duplicate labels removed
# train: /kaggle/working/images/bothFireAndSmoke_CV010901.jpg: 1 duplicate labels removed
# train: /kaggle/working/images/bothFireAndSmoke_CV010934.jpg: 1 duplicate labels removed
# train: /kaggle/working/images/bothFireAndSmoke_CV011072.jpg: 1 duplicate labels removed
# train: /kaggle/working/images/bothFireAndSmoke_CV011085.jpg: 1 duplicate labels removed
# train: /kaggle/working/images/bothFireAndSmoke_CV011149.jpg: 1 duplicate labels removed
# train: /kaggle/working/images/bothFireAndSmoke_CV011174.jpg: 1 duplicate labels removed
# train: /kaggle/working/images/bothFireAndSmoke_CV011185.jpg: 1 duplicate labels removed
# train: /kaggle/working/images/bothFireAndSmoke_CV011190.jpg: 1 duplicate labels removed
# train: /kaggle/working/images/bothFireAndSmoke_CV011231.jpg: 1 duplicate labels removed
# train: /kaggle/working/images/bothFireAndSmoke_CV011386.jpg: 1 duplicate labels removed
# train: /kaggle/working/images/bothFireAndSmoke_CV011453.jpg: 1 duplicate labels removed
# train: /kaggle/working/images/bothFireAndSmoke_CV011656.jpg: 1 duplicate labels removed
# train: /kaggle/working/images/bothFireAndSmoke_CV011713.jpg: 1 duplicate labels removed
# train: /kaggle/working/images/bothFireAndSmoke_CV011742.jpg: 1 duplicate labels removed
# train: /kaggle/working/images/bothFireAndSmoke_CV011764.jpg: 1 duplicate labels removed
# train: /kaggle/working/images/bothFireAndSmoke_CV011931.jpg: 1 duplicate labels removed
# train: /kaggle/working/images/bothFireAndSmoke_CV012059.jpg: 1 duplicate labels removed
# train: /kaggle/working/images/bothFireAndSmoke_CV012062.jpg: 1 duplicate labels removed
# train: /kaggle/working/images/bothFireAndSmoke_CV012160.jpg: 1 duplicate labels removed
# train: /kaggle/working/images/bothFireAndSmoke_CV012225.jpg: 1 duplicate labels removed
# train: /kaggle/working/images/bothFireAndSmoke_CV012308.jpg: 1 duplicate labels removed
# train: /kaggle/working/images/bothFireAndSmoke_CV012869.jpg: 1 duplicate labels removed
# train: /kaggle/working/images/bothFireAndSmoke_CV012870.jpg: 1 duplicate labels removed
# train: /kaggle/working/images/bothFireAndSmoke_CV012880.jpg: 1 duplicate labels removed
# train: /kaggle/working/images/bothFireAndSmoke_CV012965.jpg: 1 duplicate labels removed
# train: /kaggle/working/images/bothFireAndSmoke_CV012974.jpg: 2 duplicate labels removed
# train: /kaggle/working/images/bothFireAndSmoke_CV013243.jpg: 1 duplicate labels removed
# train: /kaggle/working/images/bothFireAndSmoke_CV013299.jpg: 1 duplicate labels removed
# train: /kaggle/working/images/bothFireAndSmoke_CV013337.jpg: 1 duplicate labels removed
# train: /kaggle/working/images/bothFireAndSmoke_CV013360.jpg: 1 duplicate labels removed
# train: /kaggle/working/images/bothFireAndSmoke_CV013372.jpg: 1 duplicate labels removed
# train: /kaggle/working/images/bothFireAndSmoke_CV013409.jpg: 1 duplicate labels removed
# train: /kaggle/working/images/bothFireAndSmoke_CV013413.jpg: 1 duplicate labels removed
# train: /kaggle/working/images/bothFireAndSmoke_CV013480.jpg: 1 duplicate labels removed
# train: /kaggle/working/images/bothFireAndSmoke_CV013491.jpg: 1 duplicate labels removed
# train: /kaggle/working/images/bothFireAndSmoke_CV013516.jpg: 1 duplicate labels removed
# train: /kaggle/working/images/bothFireAndSmoke_CV013521.jpg: 1 duplicate labels removed
# train: /kaggle/working/images/bothFireAndSmoke_CV013552.jpg: 1 duplicate labels removed
# train: /kaggle/working/images/bothFireAndSmoke_CV013583.jpg: 1 duplicate labels removed
# train: /kaggle/working/images/bothFireAndSmoke_CV013690.jpg: 1 duplicate labels removed
# train: /kaggle/working/images/bothFireAndSmoke_CV013719.jpg: 1 duplicate labels removed
# train: /kaggle/working/images/bothFireAndSmoke_CV013761.jpg: 2 duplicate labels removed
# train: /kaggle/working/images/bothFireAndSmoke_CV013819.jpg: 1 duplicate labels removed
# train: /kaggle/working/images/bothFireAndSmoke_CV013827.jpg: 1 duplicate labels removed
# train: /kaggle/working/images/bothFireAndSmoke_CV013971.jpg: 1 duplicate labels removed
# train: /kaggle/working/images/bothFireAndSmoke_CV013975.jpg: 1 duplicate labels removed
# train: /kaggle/working/images/bothFireAndSmoke_CV013983.jpg: 1 duplicate labels removed
# train: /kaggle/working/images/bothFireAndSmoke_CV013998.jpg: 1 duplicate labels removed
# train: /kaggle/working/images/bothFireAndSmoke_CV014004.jpg: 1 duplicate labels removed
# train: /kaggle/working/images/bothFireAndSmoke_CV014014.jpg: 1 duplicate labels removed
# train: /kaggle/working/images/bothFireAndSmoke_CV014035.jpg: 1 duplicate labels removed
# train: /kaggle/working/images/bothFireAndSmoke_CV014042.jpg: 1 duplicate labels removed
# train: /kaggle/working/images/bothFireAndSmoke_CV014083.jpg: 1 duplicate labels removed
# train: /kaggle/working/images/bothFireAndSmoke_CV014089.jpg: 1 duplicate labels removed
# train: /kaggle/working/images/bothFireAndSmoke_CV014093.jpg: 1 duplicate labels removed
# train: /kaggle/working/images/bothFireAndSmoke_CV014110.jpg: 1 duplicate labels removed
# train: /kaggle/working/images/bothFireAndSmoke_CV014122.jpg: 1 duplicate labels removed
# train: /kaggle/working/images/bothFireAndSmoke_CV014126.jpg: 1 duplicate labels removed
# train: /kaggle/working/images/bothFireAndSmoke_CV014133.jpg: 1 duplicate labels removed
# train: /kaggle/working/images/bothFireAndSmoke_CV014138.jpg: 1 duplicate labels removed
# train: /kaggle/working/images/bothFireAndSmoke_CV014190.jpg: 1 duplicate labels removed
# train: /kaggle/working/images/bothFireAndSmoke_CV014256.jpg: 1 duplicate labels removed
# train: /kaggle/working/images/bothFireAndSmoke_CV014261.jpg: 1 duplicate labels removed
# train: /kaggle/working/images/bothFireAndSmoke_CV014264.jpg: 1 duplicate labels removed
# train: /kaggle/working/images/bothFireAndSmoke_CV014316.jpg: 1 duplicate labels removed
# train: /kaggle/working/images/bothFireAndSmoke_CV014352.jpg: 1 duplicate labels removed
# train: /kaggle/working/images/bothFireAndSmoke_CV014425.jpg: 1 duplicate labels removed
# train: /kaggle/working/images/bothFireAndSmoke_CV014436.jpg: 1 duplicate labels removed
# train: /kaggle/working/images/bothFireAndSmoke_CV014439.jpg: 2 duplicate labels removed
# train: /kaggle/working/images/bothFireAndSmoke_CV014440.jpg: 1 duplicate labels removed
# train: /kaggle/working/images/bothFireAndSmoke_CV014442.jpg: 1 duplicate labels removed
# train: /kaggle/working/images/bothFireAndSmoke_CV014446.jpg: 1 duplicate labels removed
# train: /kaggle/working/images/bothFireAndSmoke_CV014462.jpg: 1 duplicate labels removed
# train: /kaggle/working/images/bothFireAndSmoke_CV014466.jpg: 2 duplicate labels removed
# train: /kaggle/working/images/bothFireAndSmoke_CV014474.jpg: 1 duplicate labels removed
# train: /kaggle/working/images/bothFireAndSmoke_CV014479.jpg: 2 duplicate labels removed
# train: /kaggle/working/images/bothFireAndSmoke_CV014495.jpg: 1 duplicate labels removed
# train: /kaggle/working/images/bothFireAndSmoke_CV014502.jpg: 1 duplicate labels removed
# train: /kaggle/working/images/bothFireAndSmoke_CV014504.jpg: 1 duplicate labels removed
# train: /kaggle/working/images/bothFireAndSmoke_CV014505.jpg: 1 duplicate labels removed
# train: /kaggle/working/images/bothFireAndSmoke_CV014522.jpg: 1 duplicate labels removed
# train: /kaggle/working/images/bothFireAndSmoke_CV014531.jpg: 1 duplicate labels removed
# train: /kaggle/working/images/bothFireAndSmoke_CV014538.jpg: 1 duplicate labels removed
# train: /kaggle/working/images/bothFireAndSmoke_CV014548.jpg: 1 duplicate labels removed
# train: /kaggle/working/images/bothFireAndSmoke_CV014574.jpg: 1 duplicate labels removed
# train: /kaggle/working/images/bothFireAndSmoke_CV014580.jpg: 1 duplicate labels removed
# train: /kaggle/working/images/bothFireAndSmoke_CV014593.jpg: 1 duplicate labels removed
# train: /kaggle/working/images/bothFireAndSmoke_CV014605.jpg: 1 duplicate labels removed
# train: /kaggle/working/images/bothFireAndSmoke_CV014606.jpg: 1 duplicate labels removed
# train: /kaggle/working/images/bothFireAndSmoke_CV014619.jpg: 1 duplicate labels removed
# train: /kaggle/working/images/bothFireAndSmoke_CV014629.jpg: 1 duplicate labels removed
# train: /kaggle/working/images/bothFireAndSmoke_CV014703.jpg: 1 duplicate labels removed
# train: /kaggle/working/images/bothFireAndSmoke_CV014712.jpg: 1 duplicate labels removed
# train: /kaggle/working/images/bothFireAndSmoke_CV014737.jpg: 1 duplicate labels removed
# train: /kaggle/working/images/bothFireAndSmoke_CV014741.jpg: 1 duplicate labels removed
# train: /kaggle/working/images/bothFireAndSmoke_CV014755.jpg: 1 duplicate labels removed
# train: /kaggle/working/images/bothFireAndSmoke_CV014780.jpg: 1 duplicate labels removed
# train: /kaggle/working/images/bothFireAndSmoke_CV014796.jpg: 1 duplicate labels removed
# train: /kaggle/working/images/bothFireAndSmoke_CV014802.jpg: 1 duplicate labels removed
# train: /kaggle/working/images/bothFireAndSmoke_CV014899.jpg: 1 duplicate labels removed
# train: /kaggle/working/images/bothFireAndSmoke_CV014923.jpg: 1 duplicate labels removed
# train: /kaggle/working/images/bothFireAndSmoke_CV014924.jpg: 1 duplicate labels removed
# train: /kaggle/working/images/bothFireAndSmoke_CV014957.jpg: 1 duplicate labels removed
# train: /kaggle/working/images/bothFireAndSmoke_CV015017.jpg: 1 duplicate labels removed
# train: /kaggle/working/images/bothFireAndSmoke_CV015027.jpg: 1 duplicate labels removed
# train: /kaggle/working/images/bothFireAndSmoke_CV015057.jpg: 1 duplicate labels removed
# train: /kaggle/working/images/bothFireAndSmoke_CV015083.jpg: 1 duplicate labels removed
# train: /kaggle/working/images/bothFireAndSmoke_CV015093.jpg: 1 duplicate labels removed
# train: /kaggle/working/images/bothFireAndSmoke_CV015099.jpg: 1 duplicate labels removed
# train: /kaggle/working/images/bothFireAndSmoke_CV015109.jpg: 1 duplicate labels removed
# train: /kaggle/working/images/bothFireAndSmoke_CV015128.jpg: 1 duplicate labels removed
# train: /kaggle/working/images/bothFireAndSmoke_CV015152.jpg: 1 duplicate labels removed
# train: /kaggle/working/images/bothFireAndSmoke_CV015170.jpg: 3 duplicate labels removed
# train: /kaggle/working/images/bothFireAndSmoke_CV015171.jpg: 1 duplicate labels removed
# train: /kaggle/working/images/bothFireAndSmoke_CV015186.jpg: 1 duplicate labels removed
# train: /kaggle/working/images/bothFireAndSmoke_CV015207.jpg: 1 duplicate labels removed
# train: /kaggle/working/images/bothFireAndSmoke_CV015230.jpg: 1 duplicate labels removed
# train: /kaggle/working/images/bothFireAndSmoke_CV015260.jpg: 1 duplicate labels removed
# train: /kaggle/working/images/bothFireAndSmoke_CV015277.jpg: 1 duplicate labels removed
# train: /kaggle/working/images/bothFireAndSmoke_CV015278.jpg: 1 duplicate labels removed
# train: /kaggle/working/images/bothFireAndSmoke_CV015283.jpg: 1 duplicate labels removed
# train: /kaggle/working/images/bothFireAndSmoke_CV015284.jpg: 1 duplicate labels removed
# train: /kaggle/working/images/bothFireAndSmoke_CV015326.jpg: 1 duplicate labels removed
# train: /kaggle/working/images/bothFireAndSmoke_CV015336.jpg: 1 duplicate labels removed
# train: /kaggle/working/images/bothFireAndSmoke_CV015344.jpg: 1 duplicate labels removed
# train: /kaggle/working/images/bothFireAndSmoke_CV015346.jpg: 1 duplicate labels removed
# train: /kaggle/working/images/bothFireAndSmoke_CV015365.jpg: 1 duplicate labels removed
# train: /kaggle/working/images/bothFireAndSmoke_CV015385.jpg: 1 duplicate labels removed
# train: /kaggle/working/images/bothFireAndSmoke_CV015392.jpg: 1 duplicate labels removed
# train: /kaggle/working/images/bothFireAndSmoke_CV015444.jpg: 1 duplicate labels removed
# train: /kaggle/working/images/bothFireAndSmoke_CV015461.jpg: 2 duplicate labels removed
# train: /kaggle/working/images/bothFireAndSmoke_CV015478.jpg: 1 duplicate labels removed
# train: /kaggle/working/images/bothFireAndSmoke_CV015481.jpg: 1 duplicate labels removed
# train: /kaggle/working/images/bothFireAndSmoke_CV015497.jpg: 1 duplicate labels removed
# train: /kaggle/working/images/bothFireAndSmoke_CV015513.jpg: 1 duplicate labels removed
# train: /kaggle/working/images/bothFireAndSmoke_CV015520.jpg: 2 duplicate labels removed
# train: /kaggle/working/images/bothFireAndSmoke_CV015532.jpg: 1 duplicate labels removed
# train: /kaggle/working/images/bothFireAndSmoke_CV015538.jpg: 1 duplicate labels removed
# train: /kaggle/working/images/bothFireAndSmoke_CV015551.jpg: 1 duplicate labels removed
# train: /kaggle/working/images/bothFireAndSmoke_CV015578.jpg: 1 duplicate labels removed
# train: /kaggle/working/images/bothFireAndSmoke_CV015586.jpg: 2 duplicate labels removed
# train: /kaggle/working/images/bothFireAndSmoke_CV015619.jpg: 1 duplicate labels removed
# train: /kaggle/working/images/bothFireAndSmoke_CV015630.jpg: 1 duplicate labels removed
# train: /kaggle/working/images/bothFireAndSmoke_CV015650.jpg: 1 duplicate labels removed
# train: /kaggle/working/images/bothFireAndSmoke_CV015672.jpg: 1 duplicate labels removed
# train: /kaggle/working/images/bothFireAndSmoke_CV015741.jpg: 1 duplicate labels removed
# train: /kaggle/working/images/bothFireAndSmoke_CV015766.jpg: 1 duplicate labels removed
# train: /kaggle/working/images/bothFireAndSmoke_CV015804.jpg: 1 duplicate labels removed
# train: /kaggle/working/images/bothFireAndSmoke_CV015879.jpg: 1 duplicate labels removed
# train: /kaggle/working/images/bothFireAndSmoke_CV015890.jpg: 1 duplicate labels removed
# train: /kaggle/working/images/bothFireAndSmoke_CV015891.jpg: 1 duplicate labels removed
# train: /kaggle/working/images/bothFireAndSmoke_CV015915.jpg: 1 duplicate labels removed
# train: /kaggle/working/images/bothFireAndSmoke_CV015929.jpg: 1 duplicate labels removed
# train: /kaggle/working/images/bothFireAndSmoke_CV015951.jpg: 1 duplicate labels removed
# train: /kaggle/working/images/bothFireAndSmoke_CV015980.jpg: 1 duplicate labels removed
# train: /kaggle/working/images/bothFireAndSmoke_CV015984.jpg: 1 duplicate labels removed
# train: /kaggle/working/images/bothFireAndSmoke_CV015998.jpg: 1 duplicate labels removed
# train: /kaggle/working/images/bothFireAndSmoke_CV016043.jpg: 1 duplicate labels removed
# train: /kaggle/working/images/bothFireAndSmoke_CV016067.jpg: 2 duplicate labels removed
# train: /kaggle/working/images/bothFireAndSmoke_CV016086.jpg: 1 duplicate labels removed
# train: /kaggle/working/images/bothFireAndSmoke_CV016096.jpg: 1 duplicate labels removed
# train: /kaggle/working/images/bothFireAndSmoke_CV016111.jpg: 2 duplicate labels removed
# train: /kaggle/working/images/bothFireAndSmoke_CV016123.jpg: 1 duplicate labels removed
# train: /kaggle/working/images/bothFireAndSmoke_CV016125.jpg: 1 duplicate labels removed
# train: /kaggle/working/images/bothFireAndSmoke_CV016133.jpg: 1 duplicate labels removed
# train: /kaggle/working/images/bothFireAndSmoke_CV016141.jpg: 1 duplicate labels removed
# train: /kaggle/working/images/bothFireAndSmoke_CV016156.jpg: 1 duplicate labels removed
# ...
# Warning: unknown JFIF revision number 32.23
#      23/100      11.9G      1.062      2.236      1.216      1.356          0         36       1024: 100% ━━━━━━━━━━━━ 2979/2979 1.1s/it 54:111.0ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 993/993 2.0it/s 8:280.6ss
#                    all      31770      41985      0.748       0.65      0.739      0.521       0.74      0.639      0.718      0.458
#
#       Epoch    GPU_mem   box_loss   seg_loss   cls_loss   dfl_loss   sem_loss  Instances       Size
#      24/100        12G      1.055      2.214      1.203       1.36          0         43       1024: 69% ━━━━━━━━──── 2060/2979 1.1s/it 37:26<17:04
# Warning: unknown JFIF revision number 32.23
#      24/100        12G       1.06      2.215       1.21      1.361          0         24       1024: 100% ━━━━━━━━━━━━ 2979/2979 1.1s/it 54:051.0ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 993/993 2.0it/s 8:270.6ss
#                    all      31770      41985      0.748      0.651       0.74      0.522      0.741      0.637      0.718      0.459
#
#       Epoch    GPU_mem   box_loss   seg_loss   cls_loss   dfl_loss   sem_loss  Instances       Size
#      25/100      11.9G      1.059      2.217      1.199      1.354          0         21       1024: 27% ━━━───────── 818/2979 1.1s/it 14:53<38:53
# Warning: unknown JFIF revision number 32.23
#      25/100      11.9G      1.058      2.225      1.206      1.358          0         15       1024: 100% ━━━━━━━━━━━━ 2979/2979 1.1s/it 54:011.0ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 993/993 2.0it/s 8:290.6ss
#                    all      31770      41985      0.749       0.65       0.74      0.522      0.743      0.637      0.718      0.459
#
#       Epoch    GPU_mem   box_loss   seg_loss   cls_loss   dfl_loss   sem_loss  Instances       Size
#      26/100      12.1G      1.052      2.208      1.192      1.354          0         13       1024: 66% ━━━━━━━╸──── 1972/2979 1.1s/it 35:40<17:48
# Warning: unknown JFIF revision number 32.23
#      26/100      12.1G      1.054      2.218      1.201      1.353          0         17       1024: 100% ━━━━━━━━━━━━ 2979/2979 1.1s/it 53:571.0ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 993/993 2.0it/s 8:270.6ss
#                    all      31770      41985      0.749       0.65      0.741      0.523      0.742      0.638      0.719       0.46
#
#       Epoch    GPU_mem   box_loss   seg_loss   cls_loss   dfl_loss   sem_loss  Instances       Size
#      27/100      11.8G      1.071       2.24      1.231      1.367          0         26       1024: 11% ━─────────── 351/2979 1.1s/it 6:21<48:23
# Warning: unknown JFIF revision number 32.23
#      27/100      11.8G      1.047      2.203      1.191      1.347          0          6       1024: 100% ━━━━━━━━━━━━ 2979/2979 1.1s/it 53:511.0ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 993/993 2.0it/s 8:240.6ss
#                    all      31770      41985       0.75      0.651      0.742      0.524      0.743      0.638       0.72      0.461
#
#       Epoch    GPU_mem   box_loss   seg_loss   cls_loss   dfl_loss   sem_loss  Instances       Size
#      28/100        12G      1.041      2.212      1.181      1.345          0         25       1024: 33% ━━━━──────── 996/2979 1.1s/it 18:02<36:28
# Warning: unknown JFIF revision number 32.23
#      28/100        12G      1.051      2.207      1.184      1.346          0         12       1024: 100% ━━━━━━━━━━━━ 2979/2979 1.1s/it 54:091.0ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 993/993 1.9it/s 8:350.6ss
#                    all      31770      41985      0.749      0.653      0.743      0.525      0.743      0.639      0.721      0.461
#
#       Epoch    GPU_mem   box_loss   seg_loss   cls_loss   dfl_loss   sem_loss  Instances       Size
#      29/100      11.9G      1.033      2.169      1.158      1.333          0         21       1024: 72% ━━━━━━━━╸─── 2164/2979 1.1s/it 39:28<14:24
# Warning: unknown JFIF revision number 32.23
#      29/100      11.9G      1.036      2.174      1.164      1.337          0         19       1024: 100% ━━━━━━━━━━━━ 2979/2979 1.1s/it 54:151.0ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 993/993 1.9it/s 8:330.5ss
#                    all      31770      41985      0.749      0.654      0.743      0.526      0.748      0.637      0.721      0.462
#
#       Epoch    GPU_mem   box_loss   seg_loss   cls_loss   dfl_loss   sem_loss  Instances       Size
#      30/100      12.1G       1.04      2.182      1.172      1.335          0         30       1024: 64% ━━━━━━━╸──── 1917/2979 1.1s/it 34:55<18:45
# Warning: unknown JFIF revision number 32.23
#      30/100      12.1G      1.041      2.178       1.17      1.339          0         20       1024: 88% ━━━━━━━━━━╸─ 2634/2979 1.1s/it 47:59<6:264
# W0615 12:44:50.375000 129 torch/distributed/elastic/agent/server/api.py:739] Received 2 death signal, shutting down workers
# W0615 12:44:50.378000 129 torch/distributed/elastic/multiprocessing/api.py:1010] Sending process 132 closing signal SIGINT
# W0615 12:44:50.379000 129 torch/distributed/elastic/multiprocessing/api.py:1010] Sending process 133 closing signal SIGINT
# [rank1]: Traceback (most recent call last):
# [rank1]:   File "/root/.config/Ultralytics/DDP/_temp_uqq1z8rd134991495307936.py", line 19, in <module>
# [rank1]:     results = trainer.train()
# [rank1]:               ^^^^^^^^^^^^^^^
# [rank1]:   File "/usr/local/lib/python3.12/dist-packages/ultralytics/engine/trainer.py", line 246, in train
# [rank1]:     self._do_train()
# [rank1]:   File "/usr/local/lib/python3.12/dist-packages/ultralytics/engine/trainer.py", line 451, in _do_train
# [rank1]:     loss, self.loss_items = self.model(batch)
# [rank1]:                             ^^^^^^^^^^^^^^^^^
# [rank1]:   File "/usr/local/lib/python3.12/dist-packages/torch/nn/modules/module.py", line 1776, in _wrapped_call_impl
# [rank1]:     return self._call_impl(*args, **kwargs)
# [rank1]:            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# [rank1]:   File "/usr/local/lib/python3.12/dist-packages/torch/nn/modules/module.py", line 1787, in _call_impl
# [rank1]:     return forward_call(*args, **kwargs)
# [rank1]:            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# [rank1]:   File "/usr/local/lib/python3.12/dist-packages/torch/nn/parallel/distributed.py", line 1666, in forward
# [rank1]:     else self._run_ddp_forward(*inputs, **kwargs)
# [rank1]:          ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# [rank1]:   File "/usr/local/lib/python3.12/dist-packages/torch/nn/parallel/distributed.py", line 1492, in _run_ddp_forward
# [rank1]:     return self.module(*inputs, **kwargs)  # type: ignore[index]
# [rank1]:            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# [rank1]:   File "/usr/local/lib/python3.12/dist-packages/torch/nn/modules/module.py", line 1776, in _wrapped_call_impl
# [rank1]:     return self._call_impl(*args, **kwargs)
# [rank1]:            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# [rank1]:   File "/usr/local/lib/python3.12/dist-packages/torch/nn/modules/module.py", line 1787, in _call_impl
# [rank1]:     return forward_call(*args, **kwargs)
# [rank1]:            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# [rank1]:   File "/usr/local/lib/python3.12/dist-packages/ultralytics/nn/tasks.py", line 143, in forward
# [rank1]:     return self.loss(x, *args, **kwargs)
# [rank1]:            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# [rank1]:   File "/usr/local/lib/python3.12/dist-packages/ultralytics/nn/tasks.py", line 337, in loss
# [rank1]:     return self.criterion(preds, batch)
# [rank1]:            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# [rank1]:   File "/usr/local/lib/python3.12/dist-packages/ultralytics/utils/loss.py", line 474, in __call__
# [rank1]:     return self.loss(self.parse_output(preds), batch)
# [rank1]:            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# [rank1]:   File "/usr/local/lib/python3.12/dist-packages/ultralytics/utils/loss.py", line 502, in loss
# [rank1]:     (fg_mask, target_gt_idx, target_bboxes, _, _), det_loss, _ = self.get_assigned_targets_and_loss(preds, batch)
# [rank1]:                                                                  ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# [rank1]:   File "/usr/local/lib/python3.12/dist-packages/ultralytics/utils/loss.py", line 407, in get_assigned_targets_and_loss
# [rank1]:     anchor_points, stride_tensor = make_anchors(preds["feats"], self.stride, 0.5)
# [rank1]:                                    ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# [rank1]:   File "/usr/local/lib/python3.12/dist-packages/ultralytics/utils/tal.py", line 413, in make_anchors
# [rank1]:     stride_tensor.append(torch.full((h * w, 1), stride, dtype=dtype, device=device))
# [rank1]:                          ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# [rank1]: KeyboardInterrupt
# [rank0]: Traceback (most recent call last):
# [rank0]:   File "/root/.config/Ultralytics/DDP/_temp_uqq1z8rd134991495307936.py", line 19, in <module>
# [rank0]:     results = trainer.train()
# [rank0]:               ^^^^^^^^^^^^^^^
# [rank0]:   File "/usr/local/lib/python3.12/dist-packages/ultralytics/engine/trainer.py", line 246, in train
# [rank0]:     self._do_train()
# [rank0]:   File "/usr/local/lib/python3.12/dist-packages/ultralytics/engine/trainer.py", line 451, in _do_train
# [rank0]:     loss, self.loss_items = self.model(batch)
# [rank0]:                             ^^^^^^^^^^^^^^^^^
# [rank0]:   File "/usr/local/lib/python3.12/dist-packages/torch/nn/modules/module.py", line 1776, in _wrapped_call_impl
# [rank0]:     return self._call_impl(*args, **kwargs)
# [rank0]:            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# [rank0]:   File "/usr/local/lib/python3.12/dist-packages/torch/nn/modules/module.py", line 1787, in _call_impl
# [rank0]:     return forward_call(*args, **kwargs)
# [rank0]:            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# [rank0]:   File "/usr/local/lib/python3.12/dist-packages/torch/nn/parallel/distributed.py", line 1666, in forward
# [rank0]:     else self._run_ddp_forward(*inputs, **kwargs)
# [rank0]:          ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# [rank0]:   File "/usr/local/lib/python3.12/dist-packages/torch/nn/parallel/distributed.py", line 1492, in _run_ddp_forward
# [rank0]:     return self.module(*inputs, **kwargs)  # type: ignore[index]
# [rank0]:            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# [rank0]:   File "/usr/local/lib/python3.12/dist-packages/torch/nn/modules/module.py", line 1776, in _wrapped_call_impl
# [rank0]:     return self._call_impl(*args, **kwargs)
# [rank0]:            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# [rank0]:   File "/usr/local/lib/python3.12/dist-packages/torch/nn/modules/module.py", line 1787, in _call_impl
# [rank0]:     return forward_call(*args, **kwargs)
# [rank0]:            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# [rank0]:   File "/usr/local/lib/python3.12/dist-packages/ultralytics/nn/tasks.py", line 143, in forward
# [rank0]:     return self.loss(x, *args, **kwargs)
# [rank0]:            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# [rank0]:   File "/usr/local/lib/python3.12/dist-packages/ultralytics/nn/tasks.py", line 337, in loss
# [rank0]:     return self.criterion(preds, batch)
# [rank0]:            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# [rank0]:   File "/usr/local/lib/python3.12/dist-packages/ultralytics/utils/loss.py", line 474, in __call__
# [rank0]:     return self.loss(self.parse_output(preds), batch)
# [rank0]:            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# [rank0]:   File "/usr/local/lib/python3.12/dist-packages/ultralytics/utils/loss.py", line 502, in loss
# [rank0]:     (fg_mask, target_gt_idx, target_bboxes, _, _), det_loss, _ = self.get_assigned_targets_and_loss(preds, batch)
# [rank0]:                                                                  ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# [rank0]:   File "/usr/local/lib/python3.12/dist-packages/ultralytics/utils/loss.py", line 407, in get_assigned_targets_and_loss
# [rank0]:     anchor_points, stride_tensor = make_anchors(preds["feats"], self.stride, 0.5)
# [rank0]:                                    ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# [rank0]:   File "/usr/local/lib/python3.12/dist-packages/ultralytics/utils/tal.py", line 413, in make_anchors
# [rank0]:     stride_tensor.append(torch.full((h * w, 1), stride, dtype=dtype, device=device))
# [rank0]:                          ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# [rank0]: KeyboardInterrupt
#      30/100      12.1G      1.041      2.178       1.17      1.339          0         20       1024: 88% ━━━━━━━━━━╸─ 2635/2979 1.5it/s 47:59<3:54
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /tmp/ipykernel_58/3172643542.py in <cell line: 0>()
#     100         print("\n[resume] Starting true Ultralytics resume from last.pt...")
#     101         model = YOLO(str(working_last_pt))
# --> 102         results = model.train(resume=True)
#     103     elif working_last_pt.exists():
#     104         print("\n[resume] WARNING: args.yaml missing.")
#
# /usr/local/lib/python3.12/dist-packages/ultralytics/engine/model.py in train(self, trainer, **kwargs)
#     790             self.model = self.trainer.model
#     791
# --> 792         self.trainer.train()
#     793         # Update model and cfg after training
#     794         if RANK in {-1, 0}:
#
# /usr/local/lib/python3.12/dist-packages/ultralytics/engine/trainer.py in train(self)
#     236                 cmd, file = generate_ddp_command(self)
#     237                 LOGGER.info(f"{colorstr('DDP:')} debug command {' '.join(cmd)}")
# --> 238                 subprocess.run(cmd, check=True)
#     239             except Exception as e:
#     240                 raise e
#
# /usr/lib/python3.12/subprocess.py in run(input, capture_output, timeout, check, *popenargs, **kwargs)
#     548     with Popen(*popenargs, **kwargs) as process:
#     549         try:
# --> 550             stdout, stderr = process.communicate(input, timeout=timeout)
#     551         except TimeoutExpired as exc:
#     552             process.kill()
#
# /usr/lib/python3.12/subprocess.py in communicate(self, input, timeout)
#    1199                 stderr = self.stderr.read()
#    1200                 self.stderr.close()
# -> 1201             self.wait()
#    1202         else:
#    1203             if timeout is not None:
#
# /usr/lib/python3.12/subprocess.py in wait(self, timeout)
#    1262             endtime = _time() + timeout
#    1263         try:
# -> 1264             return self._wait(timeout=timeout)
#    1265         except KeyboardInterrupt:
#    1266             # https://bugs.python.org/issue25942
#
# /usr/lib/python3.12/subprocess.py in _wait(self, timeout)
#    2051                         if self.returncode is not None:
#    2052                             break  # Another thread waited.
# -> 2053                         (pid, sts) = self._try_wait(0)
#    2054                         # Check the pid and loop as waitpid has been known to
#    2055                         # return 0 even without WNOHANG in odd situations.
#
# /usr/lib/python3.12/subprocess.py in _try_wait(self, wait_flags)
#    2009             """All callers to this function MUST hold self._waitpid_lock."""
#    2010             try:
# -> 2011                 (pid, sts) = os.waitpid(self.pid, wait_flags)
#    2012             except ChildProcessError:
#    2013                 # This happens if SIGCLD is set to be ignored or waiting
#
# KeyboardInterrupt:

# %% [markdown]
# ## S9. Post-Training Logging

# %%
try:
    active_results = results
except NameError:
    print("No training results — run S8 first.")
    active_results = None

if active_results is not None:
    rd = active_results.results_dict

    def safe(key):
        v = rd.get(key)
        return round(float(v), 4) if v is not None else None

    # Box head
    box_mAP50   = safe("metrics/mAP50(B)")
    box_mAP5095 = safe("metrics/mAP50-95(B)")
    precision   = safe("metrics/precision(B)")
    recall      = safe("metrics/recall(B)")

    # Seg head
    seg_mAP50   = safe("metrics/mAP50(M)")
    seg_mAP5095 = safe("metrics/mAP50-95(M)")

    # Per-class AP
    box_ap50_fire  = box_ap50_smoke  = None
    seg_ap50_fire  = seg_ap50_smoke  = None
    try:
        box = active_results.box
        if hasattr(box, "ap50") and len(box.ap50) >= 2:
            box_ap50_fire  = round(float(box.ap50[0]), 4)
            box_ap50_smoke = round(float(box.ap50[1]), 4)
    except Exception as e:
        print(f"Box per-class AP: {e}")

    try:
        seg = active_results.seg
        if hasattr(seg, "ap50") and len(seg.ap50) >= 2:
            seg_ap50_fire  = round(float(seg.ap50[0]), 4)
            seg_ap50_smoke = round(float(seg.ap50[1]), 4)
    except Exception as e:
        print(f"Seg per-class AP: {e}")

    ap_gap = (round(box_ap50_smoke - box_ap50_fire, 4)
              if box_ap50_fire is not None and box_ap50_smoke is not None else None)
    epochs_run = getattr(active_results, "epoch", None)

    wandb_url = None
    if WANDB_ENABLED:
        try: wandb_url = wandb.run.get_url()
        except: pass

    print("=" * 60)
    print("Post-training results:")
    print(f"  Box mAP@0.5        : {box_mAP50}")
    print(f"  Box mAP@0.5:0.95   : {box_mAP5095}")
    print(f"  Box AP50 fire      : {box_ap50_fire}")
    print(f"  Box AP50 smoke     : {box_ap50_smoke}")
    print(f"  Box AP gap (s-f)   : {ap_gap}")
    print(f"  Seg mAP@0.5        : {seg_mAP50}")
    print(f"  Seg mAP@0.5:0.95   : {seg_mAP5095}")
    print(f"  Seg AP50 fire      : {seg_ap50_fire}")
    print(f"  Seg AP50 smoke     : {seg_ap50_smoke}")
    print(f"  Precision          : {precision}")
    print(f"  Recall             : {recall}")
    print(f"  Epochs run         : {epochs_run}")
    print("=" * 60)

# %%
# ── Layer 2: update config snapshot ───────────────────────────────────────────
if active_results is not None:
    cfg_file = RUN_DIR / "run_config.json"
    if cfg_file.exists():
        with open(cfg_file) as f:
            cfg = _json.load(f)
    else:
        cfg = {}
    cfg.setdefault("results", {}).update({
        "box_mAP50": box_mAP50,       "box_mAP50_fire": box_ap50_fire,
        "box_mAP50_smoke": box_ap50_smoke, "box_mAP5095": box_mAP5095,
        "seg_mAP50": seg_mAP50,       "seg_mAP50_fire": seg_ap50_fire,
        "seg_mAP50_smoke": seg_ap50_smoke, "seg_mAP5095": seg_mAP5095,
        "AP_gap": ap_gap, "epochs_run": epochs_run, "wandb_url": wandb_url,
    })
    with open(cfg_file, "w") as f:
        _json.dump(cfg, f, indent=2)
    print(f"Layer 2 updated: {cfg_file}")

    # ── Layer 3: append to registry ──────────────────────────────────────────
    row = {
        "run_name"                 : RUN_NAME,
        "date"                     : DATE_STR,
        "model"                    : f"yolo11{YOLO_SIZE}-seg",
        "mode"                     : TRAIN_MODE,
        "imgsz"                    : IMGSZ,
        "epochs_run"               : epochs_run,
        "box_mAP50"                : box_mAP50,
        "box_mAP50_fire"           : box_ap50_fire,
        "box_mAP50_smoke"          : box_ap50_smoke,
        "box_mAP5095"              : box_mAP5095,
        "seg_mAP50"                : seg_mAP50,
        "seg_mAP50_fire"           : seg_ap50_fire,
        "seg_mAP50_smoke"          : seg_ap50_smoke,
        "seg_mAP5095"              : seg_mAP5095,
        "AP_gap_smoke_minus_fire_box": ap_gap,
        "precision"                : precision,
        "recall"                   : recall,
        "notes"                    : EXPERIMENT_NOTES,
        "wandb_run_url"            : wandb_url,
    }
    df_reg = append_to_registry(row)

    # ── Layer 1: log to wandb ─────────────────────────────────────────────────
    if WANDB_ENABLED and wandb.run:
        wandb.summary.update({
            "test/box_mAP50"  : box_mAP50,
            "test/seg_mAP50"  : seg_mAP50,
            "test/box_AP_fire": box_ap50_fire,
            "test/seg_AP_fire": seg_ap50_fire,
            "test/AP_gap"     : ap_gap,
        })
        wandb.finish()
        print(f"wandb finished: {wandb_url}")

    print("\nCurrent experiment registry:")
    show_registry()

# %% [markdown]
# ## S10. Evaluation on Official Test Split

# %%
from ultralytics import YOLO

best_pt = None
for candidate in [
    RUN_DIR / "weights" / "best.pt",
    PROJECT_DIR / RUN_NAME / "weights" / "best.pt",
    RESUME_BEST_PT if RESUME_TRAINING else Path("__no_resume_best__.pt"),
]:
    if candidate.exists():
        best_pt = candidate
        break

if best_pt is None:
    print("best.pt not found — run S8 first.")
else:
    print(f"Evaluating: {best_pt}")
    eval_model = YOLO(str(best_pt))

    metrics = eval_model.val(
        data    = str(YAML_PATH),
        split   = "test",
        imgsz   = IMGSZ,
        batch   = 32,
        device  = "0",
        verbose = True,
    )

    print("\n=== Test Split Results ===")
    print(f"Box mAP@0.5       : {metrics.box.map50:.4f}")
    print(f"Box mAP@0.5:0.95  : {metrics.box.map:.4f}")
    print(f"Box Precision     : {metrics.box.mp:.4f}")
    print(f"Box Recall        : {metrics.box.mr:.4f}")

    try:
        print(f"Seg mAP@0.5       : {metrics.seg.map50:.4f}")
        print(f"Seg mAP@0.5:0.95  : {metrics.seg.map:.4f}")
    except:
        print("Seg metrics not available")

    cls_names = {0: "fire", 1: "smoke"}
    print("\nPer-class Box AP@0.5:")
    for i, name in cls_names.items():
        if i < len(metrics.box.ap50):
            print(f"  {name:5s}: {metrics.box.ap50[i]:.4f}")
    if len(metrics.box.ap50) >= 2:
        gap = metrics.box.ap50[1] - metrics.box.ap50[0]
        print(f"  AP gap (smoke-fire): {gap:+.4f}")

    try:
        print("\nPer-class Seg AP@0.5:")
        for i, name in cls_names.items():
            if i < len(metrics.seg.ap50):
                print(f"  {name:5s}: {metrics.seg.ap50[i]:.4f}")
    except:
        pass

# %%
# Training curves from results.csv
if best_pt is not None:
    run_dir = best_pt.parent.parent
    results_csv = run_dir / "results.csv"
    if results_csv.exists():
        df_res = pd.read_csv(results_csv)
        df_res.columns = [c.strip() for c in df_res.columns]

        def find_col(candidates):
            for c in candidates:
                if c in df_res.columns: return c
            return None

        plots = [
            (["train/box_loss"],                          "Train Box Loss"),
            (["train/seg_loss"],                          "Train Seg Loss"),
            (["train/cls_loss"],                          "Train Cls Loss"),
            (["train/dfl_loss"],                          "Train DFL Loss"),
            (["metrics/mAP50(B)", "metrics/mAP_0.5"],    "Box mAP@0.5"),
            (["metrics/mAP50(M)"],                        "Seg mAP@0.5"),
        ]

        fig, axes = plt.subplots(2, 3, figsize=(17, 8))
        fig.suptitle(f"Training Curves — {RUN_NAME}", fontsize=11, fontweight="bold")
        for ax, (candidates, title) in zip(axes.ravel(), plots):
            col = find_col(candidates)
            if col:
                ax.plot(df_res.index, df_res[col], color="#3498db", lw=2)
            ax.set_title(title, fontsize=9)
            ax.set_xlabel("Epoch")
            ax.grid(alpha=0.3)
        plt.tight_layout()
        plt.savefig(WORK_DIR / "training_curves.png", dpi=130, bbox_inches="tight")
        plt.show()
    else:
        print(f"results.csv not found at {results_csv}")

# %% [markdown]
# ## S11. Inference Spot-Check

# %%
import time

if best_pt is None:
    print("Run S8 first.")
else:
    infer_model = YOLO(str(best_pt))
    test_paths  = [p.strip() for p in open(TEST_LIST)]
    CONF, IOU   = 0.25, 0.45

    # ── Latency benchmark ───────────────────────────────────────────────────
    N_WARMUP, N_BENCH = 5, 20
    bench_paths = random.sample(test_paths, N_WARMUP + N_BENCH)
    for p in bench_paths[:N_WARMUP]:
        infer_model.predict(p, imgsz=IMGSZ, conf=CONF, iou=IOU, verbose=False)
    t0 = time.perf_counter()
    for p in bench_paths[N_WARMUP:]:
        infer_model.predict(p, imgsz=IMGSZ, conf=CONF, iou=IOU, verbose=False)
    elapsed = time.perf_counter() - t0
    inf_ms  = elapsed / N_BENCH * 1000
    fps     = 1000 / inf_ms
    model_mb = round(best_pt.stat().st_size / 1e6, 1)
    print(f"Inference latency : {inf_ms:.1f} ms/img  ({fps:.1f} FPS)  Model: {model_mb} MB")

    # Update Layer 2 + 3
    if (RUN_DIR / "run_config.json").exists():
        with open(RUN_DIR / "run_config.json") as f: cfg = _json.load(f)
        cfg["results"]["inference_ms"] = round(inf_ms, 1)
        cfg["results"]["model_mb"]     = model_mb
        with open(RUN_DIR / "run_config.json", "w") as f: _json.dump(cfg, f, indent=2)
    df_reg = load_registry()
    mask_r = df_reg["run_name"] == RUN_NAME
    if mask_r.any():
        df_reg.loc[mask_r, "inference_ms_t4"] = round(inf_ms, 1)
        df_reg.loc[mask_r, "fps_t4"]          = round(fps, 1)
        df_reg.loc[mask_r, "model_mb"]        = model_mb
        df_reg.to_csv(REGISTRY_PATH, index=False)
    show_registry()

    # ── Visual spot-check 4×4 grid ──────────────────────────────────────────
    sample_paths = random.sample(test_paths, 16)
    cls_colors   = {0: (255, 80, 0), 1: (30, 120, 255)}
    cls_names_d  = {0: "fire", 1: "smoke"}

    fig, axes = plt.subplots(4, 4, figsize=(16, 14))
    fig.suptitle(f"Inference Spot-Check — conf={CONF}  imgsz={IMGSZ}", fontsize=11)
    axes = axes.ravel()

    for i, img_path in enumerate(sample_paths):
        ax = axes[i]
        img_bgr = cv2.imread(img_path)
        if img_bgr is None: ax.axis("off"); continue
        H, W  = img_bgr.shape[:2]
        img_rgb = cv2.cvtColor(img_bgr, cv2.COLOR_BGR2RGB)
        r = infer_model.predict(img_path, conf=CONF, iou=IOU, imgsz=IMGSZ, verbose=False)
        vis = img_rgb.copy()

        # Draw seg masks
        if r[0].masks is not None:
            for mask_data, cls_id in zip(r[0].masks.data, r[0].boxes.cls):
                m = mask_data.cpu().numpy().astype(np.uint8)
                m_resized = cv2.resize(m, (W, H), interpolation=cv2.INTER_NEAREST)
                c = cls_colors.get(int(cls_id), (200,200,200))
                ov = vis.copy()
                ov[m_resized > 0] = np.array(c, dtype=np.uint8)
                vis = cv2.addWeighted(vis, 0.55, ov, 0.45, 0)

        # Draw bboxes
        for box in r[0].boxes:
            xy   = box.xyxy[0].cpu().numpy().astype(int)
            conf = float(box.conf[0])
            cls  = int(box.cls[0])
            c    = cls_colors.get(cls, (200,200,200))
            cv2.rectangle(vis, (xy[0],xy[1]), (xy[2],xy[3]), c, 2)
            cv2.putText(vis, f"{cls_names_d.get(cls,'?')} {conf:.2f}",
                        (xy[0], max(xy[1]-4, 10)),
                        cv2.FONT_HERSHEY_SIMPLEX, 0.4, c, 1)

        ax.imshow(vis)
        ax.set_title(Path(img_path).name[:22], fontsize=6)
        ax.axis("off")

    plt.tight_layout()
    plt.savefig(WORK_DIR / "inference_spotcheck.png", dpi=130, bbox_inches="tight")
    plt.show()

# %% [markdown]
# ## S12. Save Checkpoints
#
# Run before session expires to preserve weights.

# %%
import subprocess

SAVE_DIR = PROJECT_DIR
ZIP_OUT  = WORK_DIR / "fasdd_cv_seg.zip"

if SAVE_DIR.exists():
    runs = sorted(SAVE_DIR.iterdir())
    print(f"Found {len(runs)} run(s) in {SAVE_DIR}:")
    for run in runs:
        weights = run / "weights"
        if weights.exists():
            best    = weights / "best.pt"
            last    = weights / "last.pt"
            best_mb = round(best.stat().st_size / 1e6, 1) if best.exists() else "missing"
            last_mb = round(last.stat().st_size / 1e6, 1) if last.exists() else "missing"
            print(f"  {run.name}: best={best_mb} MB  last={last_mb} MB")

    print(f"\nCreating {ZIP_OUT} ...")
    subprocess.run(
        ["zip", "-r", str(ZIP_OUT), "fasdd_cv"],
        cwd=str(WORK_DIR), check=True,
    )
    zip_mb = round(ZIP_OUT.stat().st_size / 1e6, 1)
    print(f"Done: fasdd_cv_seg.zip ({zip_mb} MB) — download from Output tab")
else:
    print(f"Nothing to save: {SAVE_DIR} does not exist.")
